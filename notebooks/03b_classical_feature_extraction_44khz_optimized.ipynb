# %% [markdown]
# # Notebook 03b: Classical Feature Extraction (44.1kHz Optimized)
#
# **Purpose:** Extract classical ML features at 44.1kHz with GPU acceleration and parallel processing
#
# **Performance Optimizations:**
# 1. GPU acceleration via torchaudio (M4 Mac MPS)
# 2. Batch processing with multiprocessing
# 3. Memory-efficient chunked processing
# 4. Optimized feature extraction pipeline
#
# **Key Tasks:**
# 1. Load processed audio segments at 44.1kHz
# 2. Extract MFCC features using GPU acceleration
# 3. Extract spectral features with parallel processing
# 4. Extract GFCC features (Gammatone Frequency Cepstral Coefficients)
# 5. Extract temporal features (delta and delta-delta)
# 6. Create three feature sets: MFCC-only, GFCC-only, Combined
# 7. Save unbalanced feature arrays
# 8. Log to MLflow
#
# **Outputs:**
# - `data/features/classical/mfcc_unbalanced_features_44khz.npy`
# - `data/features/classical/gfcc_unbalanced_features_44khz.npy`
# - `data/features/classical/combined_unbalanced_features_44khz.npy`
# - `data/features/classical/labels_44khz.npy`
#
# ---

# %% [markdown]
# ## 1. Import Libraries and Setup

# %%
import os
import sys
from pathlib import Path
import json
from datetime import datetime
import warnings
import gc
from functools import partial
from multiprocessing import Pool, cpu_count
from multiprocessing.pool import ThreadPool
import time
warnings.filterwarnings('ignore')

# Audio processing
import librosa
import librosa.feature
import numpy as np
import soundfile as sf

# PyTorch and torchaudio for GPU acceleration
import torch
import torchaudio
import torchaudio.transforms as T

# GFCC from spafe
try:
    from spafe.features.gfcc import gfcc
    GFCC_AVAILABLE = True
except ImportError:
    print('Warning: spafe not installed. GFCC features will be skipped.')
    GFCC_AVAILABLE = False

# Stats and utils
from scipy import stats
import pandas as pd

# MLflow
import mlflow

# DVC
import yaml

print('✓ Libraries imported')
print(f'librosa version: {librosa.__version__}')
print(f'numpy version: {np.__version__}')
print(f'torch version: {torch.__version__}')
print(f'torchaudio version: {torchaudio.__version__}')

# Check GPU availability (M4 Mac uses MPS)
if torch.backends.mps.is_available():
    device = torch.device('mps')
    print(f'✓ GPU acceleration enabled: {device}')
elif torch.cuda.is_available():
    device = torch.device('cuda')
    print(f'✓ GPU acceleration enabled: {device}')
else:
    device = torch.device('cpu')
    print('⚠ GPU not available, using CPU')

print(f'Available CPU cores: {cpu_count()}')
print(f'GFCC available: {GFCC_AVAILABLE}')
# Out:
# ✓ Libraries imported
# librosa version: 0.10.2.post1
# numpy version: 1.26.4
# torch version: 2.8.0
# torchaudio version: 2.8.0
# ✓ GPU acceleration enabled: mps
# Available CPU cores: 10
# GFCC available: True

# %% [markdown]
# ## 2. Configuration

# %%
# Paths
PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / 'data'
PROCESSED_DIR = DATA_DIR / 'processed' / 'universal'
FEATURES_DIR = DATA_DIR / 'features' / 'classical'
MANIFEST_PATH = DATA_DIR / 'processed' / 'manifest.json'
PARAMS_PATH = PROJECT_ROOT / 'params.yaml'

# Create output directory
FEATURES_DIR.mkdir(parents=True, exist_ok=True)

# Feature extraction parameters for 44.1kHz
SAMPLE_RATE = 44100  # 44.1kHz sampling
N_FFT = 2048  # Larger FFT for higher sample rate
HOP_LENGTH = 441  # ~10ms hop (44100 * 0.01)
N_MELS = 40
N_MFCC = 13
N_GFCC = 13  # Gammatone coefficients

# Processing parameters
BATCH_SIZE = 32  # Files to process at once
N_WORKERS = max(1, cpu_count() - 2)  # Leave 2 cores free
USE_GPU = device.type in ['mps', 'cuda']

print(f'Project root: {PROJECT_ROOT}')
print(f'Processed audio: {PROCESSED_DIR}')
print(f'Features output: {FEATURES_DIR}')
print(f'Sample rate: {SAMPLE_RATE} Hz')
print(f'Batch size: {BATCH_SIZE}')
print(f'Worker processes: {N_WORKERS}')
print(f'GPU acceleration: {USE_GPU}')
# Out:
# Project root: /Users/harryirving/Development/projects/ai-ml/BikeAIv5
# Processed audio: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/processed/universal
# Features output: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/features/classical
# Sample rate: 44100 Hz
# Batch size: 32
# Worker processes: 8
# GPU acceleration: True

# %% [markdown]
# ## 3. Load Manifest and Audio Paths

# %%
# Load manifest
with open(MANIFEST_PATH, 'r') as f:
    manifest = json.load(f)

# Convert to DataFrame for easier handling
df = pd.DataFrame(manifest)

print(f'Total segments: {len(df)}')
print(f'\nClass distribution:')
print(df['class'].value_counts())
print(f'\nLabel distribution:')
print(df['label'].value_counts())

# Get file paths
# Note: manifest uses 'filepath' which is relative to PROJECT_ROOT
audio_files = [PROJECT_ROOT / row['filepath'] for _, row in df.iterrows()]
labels = df['label'].values
class_names = df['class'].values

print(f'\nFirst audio file: {audio_files[0]}')
print(f'File exists: {audio_files[0].exists()}')

# Verify all files exist
missing_files = [f for f in audio_files if not f.exists()]
if missing_files:
    print(f'WARNING: {len(missing_files)} files not found!')
    print(f'First missing: {missing_files[0]}')
else:
    print(f'✓ All {len(audio_files)} files found')
# Out:
# Total segments: 59869
#
# Class distribution:
# class
# grinder       32792
# tools         19008
# background     8069
# Name: count, dtype: int64
#
# Label distribution:
# label
# 1    32792
# 0    27077
# Name: count, dtype: int64
#
# First audio file: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/processed/universal/grinder_0000_00_0000.wav
# File exists: True
# ✓ All 59869 files found

# %% [markdown]
# ## 4. GPU-Accelerated Feature Extraction Functions

# %%
def compute_stats(features_2d):
    """
    Compute statistics (mean, std, min, max) across time dimension.
    Input: (n_coeffs, n_frames)
    Output: (n_coeffs * 4,) flattened array
    """
    mean = np.mean(features_2d, axis=1)
    std = np.std(features_2d, axis=1)
    min_val = np.min(features_2d, axis=1)
    max_val = np.max(features_2d, axis=1)
    return np.concatenate([mean, std, min_val, max_val])


def extract_mfcc_gpu(waveform_tensor, sr=44100):
    """
    Extract MFCCs using torchaudio (GPU-accelerated).
    """
    # Ensure waveform is on the correct device
    waveform = waveform_tensor.to(device)
    
    # Create MFCC transform
    mfcc_transform = T.MFCC(
        sample_rate=sr,
        n_mfcc=N_MFCC,
        melkwargs={
            'n_fft': N_FFT,
            'hop_length': HOP_LENGTH,
            'n_mels': N_MELS,
            'center': False
        }
    ).to(device)
    
    # Extract MFCCs
    mfcc = mfcc_transform(waveform)  # Shape: (channel, n_mfcc, time)
    
    # Move back to CPU and convert to numpy
    mfcc_np = mfcc.squeeze(0).cpu().numpy()  # Shape: (n_mfcc, time)
    
    return mfcc_np


def extract_spectral_features_cpu(y, sr=44100):
    """
    Extract spectral features using librosa (CPU).
    Returns concatenated feature vector with stats.
    """
    features = []
    
    # Spectral Centroid
    centroid = librosa.feature.spectral_centroid(y=y, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH)[0]
    features.extend([np.mean(centroid), np.std(centroid)])
    
    # Spectral Rolloff
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH, roll_percent=0.85)[0]
    features.extend([np.mean(rolloff), np.std(rolloff)])
    
    # Spectral Bandwidth
    bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH)[0]
    features.extend([np.mean(bandwidth), np.std(bandwidth)])
    
    # Zero Crossing Rate
    zcr = librosa.feature.zero_crossing_rate(y, hop_length=HOP_LENGTH)[0]
    features.extend([np.mean(zcr), np.std(zcr)])
    
    # RMS Energy
    rms = librosa.feature.rms(y=y, hop_length=HOP_LENGTH)[0]
    features.extend([np.mean(rms), np.std(rms)])
    
    # Spectral Contrast (7 bands x 4 stats = 28 features)
    contrast = librosa.feature.spectral_contrast(y=y, sr=sr, n_fft=N_FFT, hop_length=HOP_LENGTH, n_bands=6)
    contrast_stats = compute_stats(contrast)
    features.extend(contrast_stats)
    
    # Spectral Skewness
    S = np.abs(librosa.stft(y, n_fft=N_FFT, hop_length=HOP_LENGTH))
    skewness = stats.skew(S, axis=0)
    features.extend([np.mean(skewness), np.std(skewness)])
    
    return np.array(features)


def extract_gfcc_features(y, sr=44100):
    """
    Extract GFCC (Gammatone Frequency Cepstral Coefficients) using spafe.
    
    spafe.features.gfcc.gfcc() returns a 2D array of shape (num_frames, num_ceps).
    We transpose it to (num_ceps, num_frames) to match our stats computation.
    """
    if not GFCC_AVAILABLE:
        return np.zeros(N_GFCC * 4)  # Return zeros if GFCC not available
    
    try:
        # spafe's gfcc function signature:
        # gfcc(sig, fs=16000, num_ceps=13, nfilts=26, nfft=512, low_freq=0, high_freq=None, ...)
        gfcc_features = gfcc(
            sig=y,
            fs=sr,
            num_ceps=N_GFCC,
            nfilts=26,
            nfft=N_FFT,
            low_freq=50,
            high_freq=sr//2
        )
        
        # spafe returns (num_frames, num_ceps), transpose to (num_ceps, num_frames)
        gfcc_transposed = gfcc_features.T
        
        # Compute stats
        gfcc_stats = compute_stats(gfcc_transposed)
        return gfcc_stats
        
    except Exception as e:
        print(f'GFCC extraction error: {e}')
        return np.zeros(N_GFCC * 4)


def extract_temporal_features(mfcc_2d):
    """
    Extract delta and delta-delta features from MFCCs.
    Input: (n_mfcc, time)
    Output: delta stats (52) + delta-delta stats (52)
    """
    # Delta
    delta = librosa.feature.delta(mfcc_2d, order=1)
    delta_stats = compute_stats(delta)
    
    # Delta-delta
    delta2 = librosa.feature.delta(mfcc_2d, order=2)
    delta2_stats = compute_stats(delta2)
    
    return np.concatenate([delta_stats, delta2_stats])


print('✓ Feature extraction functions defined')
# Out:
# ✓ Feature extraction functions defined

# %% [markdown]
# ## 5. Batch Processing Function

# %%
def extract_features_from_file(args):
    """
    Extract all features from a single audio file.
    This function is designed to be called by multiprocessing.
    """
    file_path, use_gpu = args
    
    try:
        # Load audio
        y, sr = librosa.load(str(file_path), sr=SAMPLE_RATE)
        
        # Validate sample rate
        if sr != SAMPLE_RATE:
            y = librosa.resample(y, orig_sr=sr, target_sr=SAMPLE_RATE)
            sr = SAMPLE_RATE
        
        # Extract MFCCs (GPU if available)
        if use_gpu:
            # Convert to tensor for GPU processing
            waveform = torch.from_numpy(y).float().unsqueeze(0)  # Add channel dimension
            mfcc_2d = extract_mfcc_gpu(waveform, sr)
        else:
            # Use librosa for CPU
            mfcc_2d = librosa.feature.mfcc(
                y=y, sr=sr, n_mfcc=N_MFCC, n_fft=N_FFT, hop_length=HOP_LENGTH
            )
        
        # Compute MFCC stats
        mfcc_stats = compute_stats(mfcc_2d)  # 13 * 4 = 52 features
        
        # Extract spectral features (CPU)
        spectral_feats = extract_spectral_features_cpu(y, sr)  # ~40 features
        
        # Extract GFCC features
        gfcc_stats = extract_gfcc_features(y, sr)  # 13 * 4 = 52 features
        
        # Extract temporal features (delta, delta-delta)
        temporal_feats = extract_temporal_features(mfcc_2d)  # 52 + 52 = 104 features
        
        # Combine features
        mfcc_only = mfcc_stats  # 52
        gfcc_only = gfcc_stats  # 52
        combined = np.concatenate([
            mfcc_stats,      # 52
            spectral_feats,  # ~40
            gfcc_stats,      # 52
            temporal_feats   # 104
        ])  # Total: ~248 features
        
        return {
            'mfcc': mfcc_only,
            'gfcc': gfcc_only,
            'combined': combined,
            'success': True,
            'error': None
        }
    
    except Exception as e:
        print(f'Error processing {file_path}: {str(e)}')
        return {
            'mfcc': None,
            'gfcc': None,
            'combined': None,
            'success': False,
            'error': str(e)
        }


print('✓ Batch processing function defined')
# Out:
# ✓ Batch processing function defined

# %% [markdown]
# ## 6. Extract Features with Parallel Processing

# %%
# Initialize MLflow
mlflow.set_experiment('angle_grinder_pipeline')
run_name = f'feature_extraction_44khz_{datetime.now().strftime("%Y%m%d_%H%M%S")}'

with mlflow.start_run(run_name=run_name) as run:
    # Log parameters
    mlflow.log_param('sample_rate', SAMPLE_RATE)
    mlflow.log_param('n_fft', N_FFT)
    mlflow.log_param('hop_length', HOP_LENGTH)
    mlflow.log_param('n_mfcc', N_MFCC)
    mlflow.log_param('n_gfcc', N_GFCC)
    mlflow.log_param('batch_size', BATCH_SIZE)
    mlflow.log_param('n_workers', N_WORKERS)
    mlflow.log_param('gpu_enabled', USE_GPU)
    mlflow.log_param('device', str(device))
    mlflow.log_param('total_files', len(audio_files))
    
    print('\n' + '=' * 80)
    print('Starting Feature Extraction (44.1kHz Optimized)')
    print('=' * 80)
    print(f'Total files to process: {len(audio_files)}')
    print(f'Using {N_WORKERS} worker processes')
    print(f'GPU acceleration: {USE_GPU}')
    print(f'Device: {device}')
    print('\nProcessing...')
    
    start_time = time.time()
    
    # Prepare arguments for parallel processing
    args_list = [(file_path, USE_GPU) for file_path in audio_files]
    
    # Process files in parallel
    # Note: ThreadPool is used because librosa/numpy release GIL for numeric operations
    # This allows true parallelism even in Python
    with ThreadPool(N_WORKERS) as pool:
        results = []
        total = len(args_list)
        
        # Process in batches to monitor progress
        for i in range(0, total, BATCH_SIZE):
            batch_args = args_list[i:i+BATCH_SIZE]
            batch_results = pool.map(extract_features_from_file, batch_args)
            results.extend(batch_results)
            
            # Progress update
            progress = min(i + BATCH_SIZE, total)
            elapsed = time.time() - start_time
            rate = progress / elapsed if elapsed > 0 else 0
            eta = (total - progress) / rate if rate > 0 else 0
            
            print(f'Progress: {progress}/{total} ({progress/total*100:.1f}%) | '
                  f'Rate: {rate:.1f} files/sec | '
                  f'Elapsed: {elapsed:.1f}s | '
                  f'ETA: {eta:.1f}s')
            
            # Clear memory every few batches
            if i % (BATCH_SIZE * 5) == 0:
                gc.collect()
                if USE_GPU:
                    if device.type == 'cuda':
                        torch.cuda.empty_cache()
                    elif device.type == 'mps':
                        torch.mps.empty_cache()
    
    extraction_time = time.time() - start_time
    
    print(f'\n✓ Feature extraction complete!')
    print(f'Total time: {extraction_time:.2f} seconds ({extraction_time/60:.2f} minutes)')
    print(f'Average: {extraction_time/len(audio_files):.3f} seconds per file')
    print(f'Processing rate: {len(audio_files)/extraction_time:.2f} files/second')
    
    # Log timing metrics
    mlflow.log_metric('extraction_time_seconds', extraction_time)
    mlflow.log_metric('extraction_time_minutes', extraction_time/60)
    mlflow.log_metric('avg_time_per_file', extraction_time/len(audio_files))
    mlflow.log_metric('processing_rate', len(audio_files)/extraction_time)
    
    # Check for failures
    failures = [r for r in results if not r['success']]
    successes = [r for r in results if r['success']]
    
    print(f'\nSuccessful: {len(successes)}/{len(results)}')
    print(f'Failed: {len(failures)}/{len(results)}')
    
    mlflow.log_metric('successful_extractions', len(successes))
    mlflow.log_metric('failed_extractions', len(failures))
    
    if failures:
        print('\nFailed files:')
        for i, failure in enumerate(failures[:10]):  # Show first 10
            idx = results.index(failure)
            print(f'  {audio_files[idx]}: {failure["error"]}')
        if len(failures) > 10:
            print(f'  ... and {len(failures) - 10} more')
# Out:
# 2025/12/14 18:12:43 INFO mlflow.tracking.fluent: Experiment with name 'angle_grinder_pipeline' does not exist. Creating a new experiment.
# ================================================================================
# Starting Feature Extraction (44.1kHz Optimized)
# ================================================================================
# Total files to process: 59869
# Using 8 worker processes
# GPU acceleration: True
# Device: mps
#
# Processing...
# Progress: 32/59869 (0.1%) | Rate: 16.7 files/sec | Elapsed: 1.9s | ETA: 3587.4s
# Progress: 64/59869 (0.1%) | Rate: 23.9 files/sec | Elapsed: 2.7s | ETA: 2506.1s
# Progress: 96/59869 (0.2%) | Rate: 29.7 files/sec | Elapsed: 3.2s | ETA: 2015.4s
# Progress: 128/59869 (0.2%) | Rate: 33.7 files/sec | Elapsed: 3.8s | ETA: 1772.7s
# Progress: 160/59869 (0.3%) | Rate: 36.2 files/sec | Elapsed: 4.4s | ETA: 1647.7s
# Progress: 192/59869 (0.3%) | Rate: 38.2 files/sec | Elapsed: 5.0s | ETA: 1561.3s
# Progress: 224/59869 (0.4%) | Rate: 38.4 files/sec | Elapsed: 5.8s | ETA: 1552.1s
# Progress: 256/59869 (0.4%) | Rate: 39.9 files/sec | Elapsed: 6.4s | ETA: 1494.9s
# Progress: 288/59869 (0.5%) | Rate: 41.1 files/sec | Elapsed: 7.0s | ETA: 1450.5s
# Progress: 320/59869 (0.5%) | Rate: 42.1 files/sec | Elapsed: 7.6s | ETA: 1412.9s
# Progress: 352/59869 (0.6%) | Rate: 42.9 files/sec | Elapsed: 8.2s | ETA: 1388.1s
# Progress: 384/59869 (0.6%) | Rate: 43.2 files/sec | Elapsed: 8.9s | ETA: 1378.6s
# Progress: 416/59869 (0.7%) | Rate: 43.9 files/sec | Elapsed: 9.5s | ETA: 1353.3s
# Progress: 448/59869 (0.7%) | Rate: 44.6 files/sec | Elapsed: 10.0s | ETA: 1332.6s
# Progress: 480/59869 (0.8%) | Rate: 45.2 files/sec | Elapsed: 10.6s | ETA: 1314.0s
# Progress: 512/59869 (0.9%) | Rate: 45.4 files/sec | Elapsed: 11.3s | ETA: 1306.6s
# Progress: 544/59869 (0.9%) | Rate: 45.3 files/sec | Elapsed: 12.0s | ETA: 1308.6s
# Progress: 576/59869 (1.0%) | Rate: 45.9 files/sec | Elapsed: 12.6s | ETA: 1292.4s
# Progress: 608/59869 (1.0%) | Rate: 46.3 files/sec | Elapsed: 13.1s | ETA: 1279.5s
# Progress: 640/59869 (1.1%) | Rate: 46.6 files/sec | Elapsed: 13.7s | ETA: 1271.9s
# Progress: 672/59869 (1.1%) | Rate: 47.0 files/sec | Elapsed: 14.3s | ETA: 1259.9s
# Progress: 704/59869 (1.2%) | Rate: 46.9 files/sec | Elapsed: 15.0s | ETA: 1261.5s
# Progress: 736/59869 (1.2%) | Rate: 46.8 files/sec | Elapsed: 15.7s | ETA: 1262.9s
# Progress: 768/59869 (1.3%) | Rate: 47.0 files/sec | Elapsed: 16.3s | ETA: 1258.1s
# Progress: 800/59869 (1.3%) | Rate: 47.3 files/sec | Elapsed: 16.9s | ETA: 1250.0s
# Progress: 832/59869 (1.4%) | Rate: 47.6 files/sec | Elapsed: 17.5s | ETA: 1240.9s
# Progress: 864/59869 (1.4%) | Rate: 47.4 files/sec | Elapsed: 18.2s | ETA: 1244.5s
# Progress: 896/59869 (1.5%) | Rate: 47.7 files/sec | Elapsed: 18.8s | ETA: 1236.3s
# Progress: 928/59869 (1.6%) | Rate: 48.0 files/sec | Elapsed: 19.3s | ETA: 1227.6s
# Progress: 960/59869 (1.6%) | Rate: 48.3 files/sec | Elapsed: 19.9s | ETA: 1220.3s
# Progress: 992/59869 (1.7%) | Rate: 48.4 files/sec | Elapsed: 20.5s | ETA: 1215.4s
# Progress: 1024/59869 (1.7%) | Rate: 48.3 files/sec | Elapsed: 21.2s | ETA: 1217.2s
# Progress: 1056/59869 (1.8%) | Rate: 48.5 files/sec | Elapsed: 21.8s | ETA: 1212.9s
# Progress: 1088/59869 (1.8%) | Rate: 48.7 files/sec | Elapsed: 22.3s | ETA: 1206.5s
# Progress: 1120/59869 (1.9%) | Rate: 48.9 files/sec | Elapsed: 22.9s | ETA: 1200.8s
# Progress: 1152/59869 (1.9%) | Rate: 49.1 files/sec | Elapsed: 23.5s | ETA: 1195.7s
# Progress: 1184/59869 (2.0%) | Rate: 49.1 files/sec | Elapsed: 24.1s | ETA: 1194.9s
# Progress: 1216/59869 (2.0%) | Rate: 49.2 files/sec | Elapsed: 24.7s | ETA: 1191.8s
# Progress: 1248/59869 (2.1%) | Rate: 49.4 files/sec | Elapsed: 25.3s | ETA: 1186.6s
# Progress: 1280/59869 (2.1%) | Rate: 49.4 files/sec | Elapsed: 25.9s | ETA: 1185.2s
# Progress: 1312/59869 (2.2%) | Rate: 49.5 files/sec | Elapsed: 26.5s | ETA: 1182.1s
# Progress: 1344/59869 (2.2%) | Rate: 49.4 files/sec | Elapsed: 27.2s | ETA: 1184.1s
# Progress: 1376/59869 (2.3%) | Rate: 49.6 files/sec | Elapsed: 27.7s | ETA: 1179.6s
# Progress: 1408/59869 (2.4%) | Rate: 49.8 files/sec | Elapsed: 28.3s | ETA: 1174.6s
# Progress: 1440/59869 (2.4%) | Rate: 49.9 files/sec | Elapsed: 28.9s | ETA: 1171.8s
# Progress: 1472/59869 (2.5%) | Rate: 50.0 files/sec | Elapsed: 29.5s | ETA: 1168.3s
# Progress: 1504/59869 (2.5%) | Rate: 49.9 files/sec | Elapsed: 30.1s | ETA: 1169.8s
# Progress: 1536/59869 (2.6%) | Rate: 49.9 files/sec | Elapsed: 30.8s | ETA: 1168.1s
# Progress: 1568/59869 (2.6%) | Rate: 50.0 files/sec | Elapsed: 31.3s | ETA: 1164.9s
# Progress: 1600/59869 (2.7%) | Rate: 50.1 files/sec | Elapsed: 31.9s | ETA: 1162.9s
# Progress: 1632/59869 (2.7%) | Rate: 50.1 files/sec | Elapsed: 32.6s | ETA: 1161.8s
# Progress: 1664/59869 (2.8%) | Rate: 50.0 files/sec | Elapsed: 33.3s | ETA: 1163.2s
# Progress: 1696/59869 (2.8%) | Rate: 50.2 files/sec | Elapsed: 33.8s | ETA: 1159.4s
# Progress: 1728/59869 (2.9%) | Rate: 50.3 files/sec | Elapsed: 34.4s | ETA: 1156.4s
# Progress: 1760/59869 (2.9%) | Rate: 50.4 files/sec | Elapsed: 34.9s | ETA: 1152.6s
# Progress: 1792/59869 (3.0%) | Rate: 50.5 files/sec | Elapsed: 35.5s | ETA: 1151.1s
# Progress: 1824/59869 (3.0%) | Rate: 50.2 files/sec | Elapsed: 36.3s | ETA: 1155.3s
# Progress: 1856/59869 (3.1%) | Rate: 50.3 files/sec | Elapsed: 36.9s | ETA: 1153.3s
# Progress: 1888/59869 (3.2%) | Rate: 50.3 files/sec | Elapsed: 37.6s | ETA: 1153.7s
# Progress: 1920/59869 (3.2%) | Rate: 50.3 files/sec | Elapsed: 38.2s | ETA: 1152.0s
# Progress: 1952/59869 (3.3%) | Rate: 50.4 files/sec | Elapsed: 38.7s | ETA: 1148.9s
# Progress: 1984/59869 (3.3%) | Rate: 50.3 files/sec | Elapsed: 39.4s | ETA: 1150.8s
# Progress: 2016/59869 (3.4%) | Rate: 50.4 files/sec | Elapsed: 40.0s | ETA: 1148.0s
# Progress: 2048/59869 (3.4%) | Rate: 50.4 files/sec | Elapsed: 40.6s | ETA: 1146.7s
# Progress: 2080/59869 (3.5%) | Rate: 50.5 files/sec | Elapsed: 41.2s | ETA: 1143.9s
# Progress: 2112/59869 (3.5%) | Rate: 50.6 files/sec | Elapsed: 41.7s | ETA: 1140.7s
# Progress: 2144/59869 (3.6%) | Rate: 50.6 files/sec | Elapsed: 42.4s | ETA: 1140.7s
# Progress: 2176/59869 (3.6%) | Rate: 50.6 files/sec | Elapsed: 43.0s | ETA: 1139.6s
# Progress: 2208/59869 (3.7%) | Rate: 50.7 files/sec | Elapsed: 43.6s | ETA: 1137.5s
# Progress: 2240/59869 (3.7%) | Rate: 50.8 files/sec | Elapsed: 44.1s | ETA: 1134.8s
# Progress: 2272/59869 (3.8%) | Rate: 50.8 files/sec | Elapsed: 44.7s | ETA: 1133.2s
# Progress: 2304/59869 (3.8%) | Rate: 50.7 files/sec | Elapsed: 45.4s | ETA: 1134.6s
# Progress: 2336/59869 (3.9%) | Rate: 50.8 files/sec | Elapsed: 46.0s | ETA: 1133.0s
# Progress: 2368/59869 (4.0%) | Rate: 50.9 files/sec | Elapsed: 46.6s | ETA: 1130.7s
# Progress: 2400/59869 (4.0%) | Rate: 50.9 files/sec | Elapsed: 47.1s | ETA: 1129.0s
# Progress: 2432/59869 (4.1%) | Rate: 51.0 files/sec | Elapsed: 47.7s | ETA: 1127.3s
# Progress: 2464/59869 (4.1%) | Rate: 50.8 files/sec | Elapsed: 48.5s | ETA: 1130.2s
# Progress: 2496/59869 (4.2%) | Rate: 50.8 files/sec | Elapsed: 49.1s | ETA: 1128.8s
# Progress: 2528/59869 (4.2%) | Rate: 50.9 files/sec | Elapsed: 49.7s | ETA: 1126.9s
# Progress: 2560/59869 (4.3%) | Rate: 50.9 files/sec | Elapsed: 50.3s | ETA: 1125.7s
# Progress: 2592/59869 (4.3%) | Rate: 50.9 files/sec | Elapsed: 50.9s | ETA: 1124.7s
# Progress: 2624/59869 (4.4%) | Rate: 50.8 files/sec | Elapsed: 51.7s | ETA: 1127.1s
# Progress: 2656/59869 (4.4%) | Rate: 50.8 files/sec | Elapsed: 52.3s | ETA: 1125.7s
# Progress: 2688/59869 (4.5%) | Rate: 50.9 files/sec | Elapsed: 52.8s | ETA: 1123.6s
# Progress: 2720/59869 (4.5%) | Rate: 50.9 files/sec | Elapsed: 53.4s | ETA: 1122.2s
# Progress: 2752/59869 (4.6%) | Rate: 51.0 files/sec | Elapsed: 54.0s | ETA: 1120.5s
# Progress: 2784/59869 (4.7%) | Rate: 50.9 files/sec | Elapsed: 54.7s | ETA: 1121.8s
# Progress: 2816/59869 (4.7%) | Rate: 50.9 files/sec | Elapsed: 55.3s | ETA: 1119.8s
# Progress: 2848/59869 (4.8%) | Rate: 50.9 files/sec | Elapsed: 56.0s | ETA: 1120.4s
# Progress: 2880/59869 (4.8%) | Rate: 51.0 files/sec | Elapsed: 56.5s | ETA: 1118.4s
# Progress: 2912/59869 (4.9%) | Rate: 51.0 files/sec | Elapsed: 57.1s | ETA: 1116.6s
# Progress: 2944/59869 (4.9%) | Rate: 51.0 files/sec | Elapsed: 57.8s | ETA: 1116.9s
# Progress: 2976/59869 (5.0%) | Rate: 51.0 files/sec | Elapsed: 58.3s | ETA: 1114.8s
# Progress: 3008/59869 (5.0%) | Rate: 51.0 files/sec | Elapsed: 59.0s | ETA: 1115.2s
# Progress: 3040/59869 (5.1%) | Rate: 51.0 files/sec | Elapsed: 59.5s | ETA: 1113.2s
# Progress: 3072/59869 (5.1%) | Rate: 51.1 files/sec | Elapsed: 60.2s | ETA: 1112.2s
# Progress: 3104/59869 (5.2%) | Rate: 51.0 files/sec | Elapsed: 60.8s | ETA: 1112.6s
# Progress: 3136/59869 (5.2%) | Rate: 51.1 files/sec | Elapsed: 61.4s | ETA: 1110.8s
# Progress: 3168/59869 (5.3%) | Rate: 51.1 files/sec | Elapsed: 62.0s | ETA: 1109.4s
# Progress: 3200/59869 (5.3%) | Rate: 51.2 files/sec | Elapsed: 62.5s | ETA: 1107.6s
# Progress: 3232/59869 (5.4%) | Rate: 51.1 files/sec | Elapsed: 63.2s | ETA: 1107.5s
# Progress: 3264/59869 (5.5%) | Rate: 51.1 files/sec | Elapsed: 63.9s | ETA: 1108.3s
# Progress: 3296/59869 (5.5%) | Rate: 51.1 files/sec | Elapsed: 64.5s | ETA: 1107.9s
# Progress: 3328/59869 (5.6%) | Rate: 51.1 files/sec | Elapsed: 65.1s | ETA: 1106.5s
# Progress: 3360/59869 (5.6%) | Rate: 51.1 files/sec | Elapsed: 65.7s | ETA: 1104.8s
# Progress: 3392/59869 (5.7%) | Rate: 51.1 files/sec | Elapsed: 66.3s | ETA: 1104.3s
# Progress: 3424/59869 (5.7%) | Rate: 51.1 files/sec | Elapsed: 67.0s | ETA: 1105.3s
# Progress: 3456/59869 (5.8%) | Rate: 51.1 files/sec | Elapsed: 67.6s | ETA: 1103.7s
# Progress: 3488/59869 (5.8%) | Rate: 51.2 files/sec | Elapsed: 68.2s | ETA: 1102.1s
# Progress: 3520/59869 (5.9%) | Rate: 51.2 files/sec | Elapsed: 68.8s | ETA: 1101.3s
# Progress: 3552/59869 (5.9%) | Rate: 51.2 files/sec | Elapsed: 69.4s | ETA: 1100.8s
# Progress: 3584/59869 (6.0%) | Rate: 51.1 files/sec | Elapsed: 70.2s | ETA: 1101.8s
# Progress: 3616/59869 (6.0%) | Rate: 51.1 files/sec | Elapsed: 70.7s | ETA: 1100.3s
# Progress: 3648/59869 (6.1%) | Rate: 51.2 files/sec | Elapsed: 71.3s | ETA: 1098.5s
# Progress: 3680/59869 (6.1%) | Rate: 51.2 files/sec | Elapsed: 71.9s | ETA: 1097.1s
# Progress: 3712/59869 (6.2%) | Rate: 51.3 files/sec | Elapsed: 72.4s | ETA: 1095.4s
# Progress: 3744/59869 (6.3%) | Rate: 51.2 files/sec | Elapsed: 73.1s | ETA: 1096.4s
# Progress: 3776/59869 (6.3%) | Rate: 51.2 files/sec | Elapsed: 73.7s | ETA: 1095.3s
# Progress: 3808/59869 (6.4%) | Rate: 51.2 files/sec | Elapsed: 74.4s | ETA: 1095.7s
# Progress: 3840/59869 (6.4%) | Rate: 51.2 files/sec | Elapsed: 75.0s | ETA: 1094.1s
# Progress: 3872/59869 (6.5%) | Rate: 51.2 files/sec | Elapsed: 75.6s | ETA: 1093.0s
# Progress: 3904/59869 (6.5%) | Rate: 51.2 files/sec | Elapsed: 76.3s | ETA: 1093.3s
# Progress: 3936/59869 (6.6%) | Rate: 51.2 files/sec | Elapsed: 76.8s | ETA: 1091.8s
# Progress: 3968/59869 (6.6%) | Rate: 51.3 files/sec | Elapsed: 77.4s | ETA: 1089.9s
# Progress: 4000/59869 (6.7%) | Rate: 51.3 files/sec | Elapsed: 78.0s | ETA: 1089.0s
# Progress: 4032/59869 (6.7%) | Rate: 51.4 files/sec | Elapsed: 78.5s | ETA: 1087.4s
# Progress: 4064/59869 (6.8%) | Rate: 51.3 files/sec | Elapsed: 79.3s | ETA: 1088.6s
# Progress: 4096/59869 (6.8%) | Rate: 51.3 files/sec | Elapsed: 79.8s | ETA: 1086.9s
# Progress: 4128/59869 (6.9%) | Rate: 51.3 files/sec | Elapsed: 80.4s | ETA: 1086.1s
# Progress: 4160/59869 (6.9%) | Rate: 51.3 files/sec | Elapsed: 81.0s | ETA: 1084.9s
# Progress: 4192/59869 (7.0%) | Rate: 51.4 files/sec | Elapsed: 81.6s | ETA: 1083.8s
# Progress: 4224/59869 (7.1%) | Rate: 51.3 files/sec | Elapsed: 82.3s | ETA: 1083.9s
# Progress: 4256/59869 (7.1%) | Rate: 51.3 files/sec | Elapsed: 82.9s | ETA: 1083.1s
# Progress: 4288/59869 (7.2%) | Rate: 51.4 files/sec | Elapsed: 83.4s | ETA: 1081.6s
# Progress: 4320/59869 (7.2%) | Rate: 51.4 files/sec | Elapsed: 84.1s | ETA: 1081.1s
# Progress: 4352/59869 (7.3%) | Rate: 51.3 files/sec | Elapsed: 84.8s | ETA: 1081.6s
# Progress: 4384/59869 (7.3%) | Rate: 51.3 files/sec | Elapsed: 85.5s | ETA: 1081.7s
# Progress: 4416/59869 (7.4%) | Rate: 51.3 files/sec | Elapsed: 86.1s | ETA: 1080.8s
# Progress: 4448/59869 (7.4%) | Rate: 51.3 files/sec | Elapsed: 86.7s | ETA: 1080.3s
# Progress: 4480/59869 (7.5%) | Rate: 51.3 files/sec | Elapsed: 87.3s | ETA: 1079.8s
# Progress: 4512/59869 (7.5%) | Rate: 51.3 files/sec | Elapsed: 87.9s | ETA: 1078.5s
# Progress: 4544/59869 (7.6%) | Rate: 51.3 files/sec | Elapsed: 88.6s | ETA: 1079.1s
# Progress: 4576/59869 (7.6%) | Rate: 51.3 files/sec | Elapsed: 89.2s | ETA: 1077.5s
# Progress: 4608/59869 (7.7%) | Rate: 51.4 files/sec | Elapsed: 89.7s | ETA: 1076.1s
# Progress: 4640/59869 (7.8%) | Rate: 51.4 files/sec | Elapsed: 90.3s | ETA: 1075.3s
# Progress: 4672/59869 (7.8%) | Rate: 51.3 files/sec | Elapsed: 91.0s | ETA: 1075.0s
# Progress: 4704/59869 (7.9%) | Rate: 51.3 files/sec | Elapsed: 91.7s | ETA: 1075.1s
# Progress: 4736/59869 (7.9%) | Rate: 51.3 files/sec | Elapsed: 92.3s | ETA: 1074.0s
# Progress: 4768/59869 (8.0%) | Rate: 51.4 files/sec | Elapsed: 92.8s | ETA: 1072.9s
# Progress: 4800/59869 (8.0%) | Rate: 51.4 files/sec | Elapsed: 93.4s | ETA: 1072.1s
# Progress: 4832/59869 (8.1%) | Rate: 51.4 files/sec | Elapsed: 94.1s | ETA: 1071.4s
# Progress: 4864/59869 (8.1%) | Rate: 51.3 files/sec | Elapsed: 94.8s | ETA: 1072.1s
# Progress: 4896/59869 (8.2%) | Rate: 51.3 files/sec | Elapsed: 95.4s | ETA: 1071.5s
# Progress: 4928/59869 (8.2%) | Rate: 51.3 files/sec | Elapsed: 96.0s | ETA: 1070.1s
# Progress: 4960/59869 (8.3%) | Rate: 51.3 files/sec | Elapsed: 96.6s | ETA: 1069.8s
# Progress: 4992/59869 (8.3%) | Rate: 51.4 files/sec | Elapsed: 97.2s | ETA: 1068.5s
# Progress: 5024/59869 (8.4%) | Rate: 51.3 files/sec | Elapsed: 97.9s | ETA: 1068.9s
# Progress: 5056/59869 (8.4%) | Rate: 51.3 files/sec | Elapsed: 98.5s | ETA: 1067.6s
# Progress: 5088/59869 (8.5%) | Rate: 51.4 files/sec | Elapsed: 99.1s | ETA: 1066.4s
# Progress: 5120/59869 (8.6%) | Rate: 51.4 files/sec | Elapsed: 99.6s | ETA: 1065.6s
# Progress: 5152/59869 (8.6%) | Rate: 51.4 files/sec | Elapsed: 100.3s | ETA: 1065.1s
# Progress: 5184/59869 (8.7%) | Rate: 51.3 files/sec | Elapsed: 101.0s | ETA: 1065.8s
# Progress: 5216/59869 (8.7%) | Rate: 51.3 files/sec | Elapsed: 101.7s | ETA: 1065.3s
# Progress: 5248/59869 (8.8%) | Rate: 51.3 files/sec | Elapsed: 102.2s | ETA: 1063.8s
# Progress: 5280/59869 (8.8%) | Rate: 51.3 files/sec | Elapsed: 102.9s | ETA: 1063.5s
# Progress: 5312/59869 (8.9%) | Rate: 51.3 files/sec | Elapsed: 103.5s | ETA: 1062.5s
# Progress: 5344/59869 (8.9%) | Rate: 51.3 files/sec | Elapsed: 104.1s | ETA: 1062.5s
# Progress: 5376/59869 (9.0%) | Rate: 51.3 files/sec | Elapsed: 104.7s | ETA: 1061.6s
# Progress: 5408/59869 (9.0%) | Rate: 51.3 files/sec | Elapsed: 105.4s | ETA: 1061.1s
# Progress: 5440/59869 (9.1%) | Rate: 51.4 files/sec | Elapsed: 105.9s | ETA: 1059.8s
# Progress: 5472/59869 (9.1%) | Rate: 51.4 files/sec | Elapsed: 106.5s | ETA: 1058.4s
# Progress: 5504/59869 (9.2%) | Rate: 51.3 files/sec | Elapsed: 107.2s | ETA: 1059.2s
# Progress: 5536/59869 (9.2%) | Rate: 51.4 files/sec | Elapsed: 107.8s | ETA: 1058.0s
# Progress: 5568/59869 (9.3%) | Rate: 51.4 files/sec | Elapsed: 108.4s | ETA: 1057.0s
# Progress: 5600/59869 (9.4%) | Rate: 51.4 files/sec | Elapsed: 109.0s | ETA: 1056.0s
# Progress: 5632/59869 (9.4%) | Rate: 51.4 files/sec | Elapsed: 109.6s | ETA: 1055.2s
# Progress: 5664/59869 (9.5%) | Rate: 51.4 files/sec | Elapsed: 110.3s | ETA: 1055.5s
# Progress: 5696/59869 (9.5%) | Rate: 51.4 files/sec | Elapsed: 110.9s | ETA: 1054.8s
# Progress: 5728/59869 (9.6%) | Rate: 51.4 files/sec | Elapsed: 111.5s | ETA: 1053.8s
# Progress: 5760/59869 (9.6%) | Rate: 51.4 files/sec | Elapsed: 112.1s | ETA: 1052.6s
# Progress: 5792/59869 (9.7%) | Rate: 51.4 files/sec | Elapsed: 112.6s | ETA: 1051.4s
# Progress: 5824/59869 (9.7%) | Rate: 51.4 files/sec | Elapsed: 113.4s | ETA: 1052.0s
# Progress: 5856/59869 (9.8%) | Rate: 51.4 files/sec | Elapsed: 114.0s | ETA: 1051.5s
# Progress: 5888/59869 (9.8%) | Rate: 51.4 files/sec | Elapsed: 114.6s | ETA: 1050.7s
# Progress: 5920/59869 (9.9%) | Rate: 51.3 files/sec | Elapsed: 115.3s | ETA: 1051.0s
# Progress: 5952/59869 (9.9%) | Rate: 51.3 files/sec | Elapsed: 116.1s | ETA: 1051.5s
# Progress: 5984/59869 (10.0%) | Rate: 51.2 files/sec | Elapsed: 116.8s | ETA: 1052.1s
# Progress: 6016/59869 (10.0%) | Rate: 51.2 files/sec | Elapsed: 117.5s | ETA: 1051.5s
# Progress: 6048/59869 (10.1%) | Rate: 51.2 files/sec | Elapsed: 118.1s | ETA: 1050.7s
# Progress: 6080/59869 (10.2%) | Rate: 51.3 files/sec | Elapsed: 118.6s | ETA: 1049.5s
# Progress: 6112/59869 (10.2%) | Rate: 51.3 files/sec | Elapsed: 119.2s | ETA: 1048.3s
# Progress: 6144/59869 (10.3%) | Rate: 51.2 files/sec | Elapsed: 119.9s | ETA: 1048.3s
# Progress: 6176/59869 (10.3%) | Rate: 51.3 files/sec | Elapsed: 120.4s | ETA: 1047.1s
# Progress: 6208/59869 (10.4%) | Rate: 51.3 files/sec | Elapsed: 121.0s | ETA: 1046.1s
# Progress: 6240/59869 (10.4%) | Rate: 51.3 files/sec | Elapsed: 121.6s | ETA: 1045.3s
# Progress: 6272/59869 (10.5%) | Rate: 51.3 files/sec | Elapsed: 122.2s | ETA: 1044.1s
# Progress: 6304/59869 (10.5%) | Rate: 51.3 files/sec | Elapsed: 123.0s | ETA: 1045.0s
# Progress: 6336/59869 (10.6%) | Rate: 51.3 files/sec | Elapsed: 123.6s | ETA: 1044.2s
# Progress: 6368/59869 (10.6%) | Rate: 51.3 files/sec | Elapsed: 124.2s | ETA: 1043.8s
# Progress: 6400/59869 (10.7%) | Rate: 51.3 files/sec | Elapsed: 124.9s | ETA: 1043.2s
# Progress: 6432/59869 (10.7%) | Rate: 51.3 files/sec | Elapsed: 125.5s | ETA: 1042.6s
# Progress: 6464/59869 (10.8%) | Rate: 51.2 files/sec | Elapsed: 126.3s | ETA: 1043.1s
# Progress: 6496/59869 (10.9%) | Rate: 51.2 files/sec | Elapsed: 126.8s | ETA: 1042.0s
# Progress: 6528/59869 (10.9%) | Rate: 51.2 files/sec | Elapsed: 127.4s | ETA: 1041.4s
# Progress: 6560/59869 (11.0%) | Rate: 51.2 files/sec | Elapsed: 128.0s | ETA: 1040.2s
# Progress: 6592/59869 (11.0%) | Rate: 51.3 files/sec | Elapsed: 128.6s | ETA: 1039.5s
# Progress: 6624/59869 (11.1%) | Rate: 51.2 files/sec | Elapsed: 129.3s | ETA: 1039.7s
# Progress: 6656/59869 (11.1%) | Rate: 51.2 files/sec | Elapsed: 129.9s | ETA: 1038.5s
# Progress: 6688/59869 (11.2%) | Rate: 51.3 files/sec | Elapsed: 130.5s | ETA: 1037.3s
# Progress: 6720/59869 (11.2%) | Rate: 51.3 files/sec | Elapsed: 131.1s | ETA: 1037.0s
# Progress: 6752/59869 (11.3%) | Rate: 51.3 files/sec | Elapsed: 131.7s | ETA: 1036.4s
# Progress: 6784/59869 (11.3%) | Rate: 51.2 files/sec | Elapsed: 132.5s | ETA: 1036.6s
# Progress: 6816/59869 (11.4%) | Rate: 51.2 files/sec | Elapsed: 133.0s | ETA: 1035.5s
# Progress: 6848/59869 (11.4%) | Rate: 51.3 files/sec | Elapsed: 133.6s | ETA: 1034.3s
# Progress: 6880/59869 (11.5%) | Rate: 51.3 files/sec | Elapsed: 134.2s | ETA: 1033.7s
# Progress: 6912/59869 (11.5%) | Rate: 51.3 files/sec | Elapsed: 134.8s | ETA: 1032.6s
# Progress: 6944/59869 (11.6%) | Rate: 51.3 files/sec | Elapsed: 135.5s | ETA: 1032.6s
# Progress: 6976/59869 (11.7%) | Rate: 51.2 files/sec | Elapsed: 136.4s | ETA: 1033.9s
# Progress: 7008/59869 (11.7%) | Rate: 51.1 files/sec | Elapsed: 137.2s | ETA: 1034.6s
# Progress: 7040/59869 (11.8%) | Rate: 51.1 files/sec | Elapsed: 137.7s | ETA: 1033.4s
# Progress: 7072/59869 (11.8%) | Rate: 51.1 files/sec | Elapsed: 138.3s | ETA: 1032.5s
# Progress: 7104/59869 (11.9%) | Rate: 51.1 files/sec | Elapsed: 139.0s | ETA: 1032.2s
# Progress: 7136/59869 (11.9%) | Rate: 51.1 files/sec | Elapsed: 139.5s | ETA: 1031.2s
# Progress: 7168/59869 (12.0%) | Rate: 51.2 files/sec | Elapsed: 140.1s | ETA: 1030.2s
# Progress: 7200/59869 (12.0%) | Rate: 51.2 files/sec | Elapsed: 140.7s | ETA: 1029.3s
# Progress: 7232/59869 (12.1%) | Rate: 51.2 files/sec | Elapsed: 141.3s | ETA: 1028.3s
# Progress: 7264/59869 (12.1%) | Rate: 51.1 files/sec | Elapsed: 142.0s | ETA: 1028.5s
# Progress: 7296/59869 (12.2%) | Rate: 51.2 files/sec | Elapsed: 142.6s | ETA: 1027.4s
# Progress: 7328/59869 (12.2%) | Rate: 51.2 files/sec | Elapsed: 143.2s | ETA: 1026.4s
# Progress: 7360/59869 (12.3%) | Rate: 51.2 files/sec | Elapsed: 143.8s | ETA: 1025.6s
# Progress: 7392/59869 (12.3%) | Rate: 51.2 files/sec | Elapsed: 144.3s | ETA: 1024.7s
# Progress: 7424/59869 (12.4%) | Rate: 51.2 files/sec | Elapsed: 145.0s | ETA: 1024.7s
# Progress: 7456/59869 (12.5%) | Rate: 51.2 files/sec | Elapsed: 145.7s | ETA: 1023.9s
# Progress: 7488/59869 (12.5%) | Rate: 51.2 files/sec | Elapsed: 146.2s | ETA: 1022.9s
# Progress: 7520/59869 (12.6%) | Rate: 51.2 files/sec | Elapsed: 146.8s | ETA: 1021.9s
# Progress: 7552/59869 (12.6%) | Rate: 51.2 files/sec | Elapsed: 147.4s | ETA: 1021.1s
# Progress: 7584/59869 (12.7%) | Rate: 51.2 files/sec | Elapsed: 148.1s | ETA: 1021.2s
# Progress: 7616/59869 (12.7%) | Rate: 51.2 files/sec | Elapsed: 148.7s | ETA: 1020.0s
# Progress: 7648/59869 (12.8%) | Rate: 51.2 files/sec | Elapsed: 149.3s | ETA: 1019.2s
# Progress: 7680/59869 (12.8%) | Rate: 51.2 files/sec | Elapsed: 149.9s | ETA: 1018.7s
# Progress: 7712/59869 (12.9%) | Rate: 51.2 files/sec | Elapsed: 150.6s | ETA: 1018.5s
# Progress: 7744/59869 (12.9%) | Rate: 51.2 files/sec | Elapsed: 151.3s | ETA: 1018.5s
# Progress: 7776/59869 (13.0%) | Rate: 51.2 files/sec | Elapsed: 152.0s | ETA: 1018.4s
# Progress: 7808/59869 (13.0%) | Rate: 51.2 files/sec | Elapsed: 152.6s | ETA: 1017.7s
# Progress: 7840/59869 (13.1%) | Rate: 51.2 files/sec | Elapsed: 153.2s | ETA: 1017.0s
# Progress: 7872/59869 (13.1%) | Rate: 51.2 files/sec | Elapsed: 153.9s | ETA: 1016.5s
# Progress: 7904/59869 (13.2%) | Rate: 51.1 files/sec | Elapsed: 154.6s | ETA: 1016.5s
# Progress: 7936/59869 (13.3%) | Rate: 51.1 files/sec | Elapsed: 155.2s | ETA: 1015.7s
# Progress: 7968/59869 (13.3%) | Rate: 51.1 files/sec | Elapsed: 155.8s | ETA: 1014.7s
# Progress: 8000/59869 (13.4%) | Rate: 51.1 files/sec | Elapsed: 156.4s | ETA: 1014.1s
# Progress: 8032/59869 (13.4%) | Rate: 51.2 files/sec | Elapsed: 157.0s | ETA: 1013.2s
# Progress: 8064/59869 (13.5%) | Rate: 51.1 files/sec | Elapsed: 157.7s | ETA: 1013.4s
# Progress: 8096/59869 (13.5%) | Rate: 51.1 files/sec | Elapsed: 158.4s | ETA: 1013.2s
# Progress: 8128/59869 (13.6%) | Rate: 51.1 files/sec | Elapsed: 159.0s | ETA: 1012.2s
# Progress: 8160/59869 (13.6%) | Rate: 51.1 files/sec | Elapsed: 159.6s | ETA: 1011.4s
# Progress: 8192/59869 (13.7%) | Rate: 51.1 files/sec | Elapsed: 160.2s | ETA: 1010.8s
# Progress: 8224/59869 (13.7%) | Rate: 51.1 files/sec | Elapsed: 160.9s | ETA: 1010.5s
# Progress: 8256/59869 (13.8%) | Rate: 51.1 files/sec | Elapsed: 161.5s | ETA: 1009.7s
# Progress: 8288/59869 (13.8%) | Rate: 51.1 files/sec | Elapsed: 162.1s | ETA: 1008.9s
# Progress: 8320/59869 (13.9%) | Rate: 51.1 files/sec | Elapsed: 162.7s | ETA: 1008.0s
# Progress: 8352/59869 (14.0%) | Rate: 51.1 files/sec | Elapsed: 163.3s | ETA: 1007.2s
# Progress: 8384/59869 (14.0%) | Rate: 51.1 files/sec | Elapsed: 164.0s | ETA: 1006.9s
# Progress: 8416/59869 (14.1%) | Rate: 51.2 files/sec | Elapsed: 164.5s | ETA: 1005.8s
# Progress: 8448/59869 (14.1%) | Rate: 51.2 files/sec | Elapsed: 165.1s | ETA: 1004.8s
# Progress: 8480/59869 (14.2%) | Rate: 51.2 files/sec | Elapsed: 165.7s | ETA: 1003.9s
# Progress: 8512/59869 (14.2%) | Rate: 51.2 files/sec | Elapsed: 166.3s | ETA: 1003.4s
# Progress: 8544/59869 (14.3%) | Rate: 51.2 files/sec | Elapsed: 167.0s | ETA: 1003.3s
# Progress: 8576/59869 (14.3%) | Rate: 51.1 files/sec | Elapsed: 167.7s | ETA: 1002.9s
# Progress: 8608/59869 (14.4%) | Rate: 51.2 files/sec | Elapsed: 168.3s | ETA: 1002.0s
# Progress: 8640/59869 (14.4%) | Rate: 51.1 files/sec | Elapsed: 169.0s | ETA: 1002.0s
# Progress: 8672/59869 (14.5%) | Rate: 51.1 files/sec | Elapsed: 169.6s | ETA: 1001.1s
# Progress: 8704/59869 (14.5%) | Rate: 51.1 files/sec | Elapsed: 170.3s | ETA: 1000.9s
# Progress: 8736/59869 (14.6%) | Rate: 51.1 files/sec | Elapsed: 170.9s | ETA: 1000.2s
# Progress: 8768/59869 (14.6%) | Rate: 51.1 files/sec | Elapsed: 171.4s | ETA: 999.1s
# Progress: 8800/59869 (14.7%) | Rate: 51.2 files/sec | Elapsed: 172.0s | ETA: 998.4s
# Progress: 8832/59869 (14.8%) | Rate: 51.1 files/sec | Elapsed: 172.7s | ETA: 998.1s
# Progress: 8864/59869 (14.8%) | Rate: 51.1 files/sec | Elapsed: 173.5s | ETA: 998.1s
# Progress: 8896/59869 (14.9%) | Rate: 51.1 files/sec | Elapsed: 174.1s | ETA: 997.7s
# Progress: 8928/59869 (14.9%) | Rate: 51.1 files/sec | Elapsed: 174.7s | ETA: 996.9s
# Progress: 8960/59869 (15.0%) | Rate: 51.1 files/sec | Elapsed: 175.3s | ETA: 996.1s
# Progress: 8992/59869 (15.0%) | Rate: 51.1 files/sec | Elapsed: 175.9s | ETA: 995.5s
# Progress: 9024/59869 (15.1%) | Rate: 51.1 files/sec | Elapsed: 176.7s | ETA: 995.5s
# Progress: 9056/59869 (15.1%) | Rate: 51.1 files/sec | Elapsed: 177.3s | ETA: 994.7s
# Progress: 9088/59869 (15.2%) | Rate: 51.1 files/sec | Elapsed: 177.9s | ETA: 994.0s
# Progress: 9120/59869 (15.2%) | Rate: 51.1 files/sec | Elapsed: 178.5s | ETA: 993.1s
# Progress: 9152/59869 (15.3%) | Rate: 51.1 files/sec | Elapsed: 179.1s | ETA: 992.8s
# Progress: 9184/59869 (15.3%) | Rate: 51.1 files/sec | Elapsed: 179.8s | ETA: 992.6s
# Progress: 9216/59869 (15.4%) | Rate: 51.1 files/sec | Elapsed: 180.5s | ETA: 991.8s
# Progress: 9248/59869 (15.4%) | Rate: 51.1 files/sec | Elapsed: 181.0s | ETA: 990.7s
# Progress: 9280/59869 (15.5%) | Rate: 51.1 files/sec | Elapsed: 181.6s | ETA: 989.8s
# Progress: 9312/59869 (15.6%) | Rate: 51.1 files/sec | Elapsed: 182.1s | ETA: 988.9s
# Progress: 9344/59869 (15.6%) | Rate: 51.1 files/sec | Elapsed: 182.9s | ETA: 988.7s
# Progress: 9376/59869 (15.7%) | Rate: 51.1 files/sec | Elapsed: 183.5s | ETA: 988.2s
# Progress: 9408/59869 (15.7%) | Rate: 51.1 files/sec | Elapsed: 184.2s | ETA: 987.8s
# Progress: 9440/59869 (15.8%) | Rate: 51.1 files/sec | Elapsed: 184.7s | ETA: 986.9s
# Progress: 9472/59869 (15.8%) | Rate: 51.1 files/sec | Elapsed: 185.3s | ETA: 986.0s
# Progress: 9504/59869 (15.9%) | Rate: 51.1 files/sec | Elapsed: 186.1s | ETA: 986.0s
# Progress: 9536/59869 (15.9%) | Rate: 51.1 files/sec | Elapsed: 186.6s | ETA: 985.2s
# Progress: 9568/59869 (16.0%) | Rate: 51.1 files/sec | Elapsed: 187.3s | ETA: 984.5s
# Progress: 9600/59869 (16.0%) | Rate: 51.1 files/sec | Elapsed: 187.9s | ETA: 983.7s
# Progress: 9632/59869 (16.1%) | Rate: 51.1 files/sec | Elapsed: 188.4s | ETA: 982.8s
# Progress: 9664/59869 (16.1%) | Rate: 51.1 files/sec | Elapsed: 189.2s | ETA: 982.9s
# Progress: 9696/59869 (16.2%) | Rate: 51.1 files/sec | Elapsed: 189.8s | ETA: 981.9s
# Progress: 9728/59869 (16.2%) | Rate: 51.1 files/sec | Elapsed: 190.3s | ETA: 981.0s
# Progress: 9760/59869 (16.3%) | Rate: 51.1 files/sec | Elapsed: 190.9s | ETA: 980.1s
# Progress: 9792/59869 (16.4%) | Rate: 51.1 files/sec | Elapsed: 191.5s | ETA: 979.2s
# Progress: 9824/59869 (16.4%) | Rate: 51.1 files/sec | Elapsed: 192.2s | ETA: 978.9s
# Progress: 9856/59869 (16.5%) | Rate: 51.1 files/sec | Elapsed: 192.8s | ETA: 978.1s
# Progress: 9888/59869 (16.5%) | Rate: 51.1 files/sec | Elapsed: 193.3s | ETA: 977.2s
# Progress: 9920/59869 (16.6%) | Rate: 51.2 files/sec | Elapsed: 193.9s | ETA: 976.3s
# Progress: 9952/59869 (16.6%) | Rate: 51.1 files/sec | Elapsed: 194.6s | ETA: 976.0s
# Progress: 9984/59869 (16.7%) | Rate: 51.1 files/sec | Elapsed: 195.2s | ETA: 975.5s
# Progress: 10016/59869 (16.7%) | Rate: 51.1 files/sec | Elapsed: 195.8s | ETA: 974.7s
# Progress: 10048/59869 (16.8%) | Rate: 51.2 files/sec | Elapsed: 196.4s | ETA: 973.8s
# Progress: 10080/59869 (16.8%) | Rate: 51.2 files/sec | Elapsed: 197.1s | ETA: 973.3s
# Progress: 10112/59869 (16.9%) | Rate: 51.2 files/sec | Elapsed: 197.7s | ETA: 972.6s
# Progress: 10144/59869 (16.9%) | Rate: 51.1 files/sec | Elapsed: 198.4s | ETA: 972.3s
# Progress: 10176/59869 (17.0%) | Rate: 51.2 files/sec | Elapsed: 198.9s | ETA: 971.5s
# Progress: 10208/59869 (17.1%) | Rate: 51.2 files/sec | Elapsed: 199.5s | ETA: 970.5s
# Progress: 10240/59869 (17.1%) | Rate: 51.2 files/sec | Elapsed: 200.1s | ETA: 970.0s
# Progress: 10272/59869 (17.2%) | Rate: 51.2 files/sec | Elapsed: 200.7s | ETA: 969.2s
# Progress: 10304/59869 (17.2%) | Rate: 51.2 files/sec | Elapsed: 201.4s | ETA: 968.9s
# Progress: 10336/59869 (17.3%) | Rate: 51.2 files/sec | Elapsed: 202.0s | ETA: 968.0s
# Progress: 10368/59869 (17.3%) | Rate: 51.2 files/sec | Elapsed: 202.6s | ETA: 967.3s
# Progress: 10400/59869 (17.4%) | Rate: 51.2 files/sec | Elapsed: 203.2s | ETA: 966.5s
# Progress: 10432/59869 (17.4%) | Rate: 51.2 files/sec | Elapsed: 203.7s | ETA: 965.5s
# Progress: 10464/59869 (17.5%) | Rate: 51.2 files/sec | Elapsed: 204.4s | ETA: 965.3s
# Progress: 10496/59869 (17.5%) | Rate: 51.2 files/sec | Elapsed: 205.0s | ETA: 964.3s
# Progress: 10528/59869 (17.6%) | Rate: 51.2 files/sec | Elapsed: 205.6s | ETA: 963.6s
# Progress: 10560/59869 (17.6%) | Rate: 51.2 files/sec | Elapsed: 206.2s | ETA: 963.0s
# Progress: 10592/59869 (17.7%) | Rate: 51.2 files/sec | Elapsed: 206.8s | ETA: 962.2s
# Progress: 10624/59869 (17.7%) | Rate: 51.2 files/sec | Elapsed: 207.5s | ETA: 961.9s
# Progress: 10656/59869 (17.8%) | Rate: 51.2 files/sec | Elapsed: 208.1s | ETA: 961.2s
# Progress: 10688/59869 (17.9%) | Rate: 51.2 files/sec | Elapsed: 208.7s | ETA: 960.3s
# Progress: 10720/59869 (17.9%) | Rate: 51.2 files/sec | Elapsed: 209.3s | ETA: 959.8s
# Progress: 10752/59869 (18.0%) | Rate: 51.2 files/sec | Elapsed: 210.0s | ETA: 959.2s
# Progress: 10784/59869 (18.0%) | Rate: 51.2 files/sec | Elapsed: 210.7s | ETA: 959.1s
# Progress: 10816/59869 (18.1%) | Rate: 51.2 files/sec | Elapsed: 211.3s | ETA: 958.2s
# Progress: 10848/59869 (18.1%) | Rate: 51.2 files/sec | Elapsed: 211.9s | ETA: 957.7s
# Progress: 10880/59869 (18.2%) | Rate: 51.2 files/sec | Elapsed: 212.7s | ETA: 957.5s
# Progress: 10912/59869 (18.2%) | Rate: 51.2 files/sec | Elapsed: 213.3s | ETA: 956.8s
# Progress: 10944/59869 (18.3%) | Rate: 51.1 files/sec | Elapsed: 214.0s | ETA: 956.7s
# Progress: 10976/59869 (18.3%) | Rate: 51.2 files/sec | Elapsed: 214.6s | ETA: 955.8s
# Progress: 11008/59869 (18.4%) | Rate: 51.2 files/sec | Elapsed: 215.2s | ETA: 955.1s
# Progress: 11040/59869 (18.4%) | Rate: 51.1 files/sec | Elapsed: 215.8s | ETA: 954.7s
# Progress: 11072/59869 (18.5%) | Rate: 51.2 files/sec | Elapsed: 216.4s | ETA: 953.9s
# Progress: 11104/59869 (18.5%) | Rate: 51.1 files/sec | Elapsed: 217.2s | ETA: 953.8s
# Progress: 11136/59869 (18.6%) | Rate: 51.1 files/sec | Elapsed: 217.9s | ETA: 953.5s
# Progress: 11168/59869 (18.7%) | Rate: 51.1 files/sec | Elapsed: 218.4s | ETA: 952.5s
# Progress: 11200/59869 (18.7%) | Rate: 51.1 files/sec | Elapsed: 219.0s | ETA: 951.8s
# Progress: 11232/59869 (18.8%) | Rate: 51.1 files/sec | Elapsed: 219.6s | ETA: 951.0s
# Progress: 11264/59869 (18.8%) | Rate: 51.1 files/sec | Elapsed: 220.4s | ETA: 951.1s
# Progress: 11296/59869 (18.9%) | Rate: 51.1 files/sec | Elapsed: 221.1s | ETA: 950.6s
# Progress: 11328/59869 (18.9%) | Rate: 51.1 files/sec | Elapsed: 221.7s | ETA: 950.0s
# Progress: 11360/59869 (19.0%) | Rate: 51.1 files/sec | Elapsed: 222.3s | ETA: 949.2s
# Progress: 11392/59869 (19.0%) | Rate: 51.1 files/sec | Elapsed: 222.9s | ETA: 948.6s
# Progress: 11424/59869 (19.1%) | Rate: 51.1 files/sec | Elapsed: 223.7s | ETA: 948.4s
# Progress: 11456/59869 (19.1%) | Rate: 51.1 files/sec | Elapsed: 224.3s | ETA: 947.7s
# Progress: 11488/59869 (19.2%) | Rate: 51.1 files/sec | Elapsed: 224.8s | ETA: 946.9s
# Progress: 11520/59869 (19.2%) | Rate: 51.1 files/sec | Elapsed: 225.4s | ETA: 946.1s
# Progress: 11552/59869 (19.3%) | Rate: 51.1 files/sec | Elapsed: 226.1s | ETA: 945.9s
# Progress: 11584/59869 (19.3%) | Rate: 51.0 files/sec | Elapsed: 226.9s | ETA: 945.9s
# Progress: 11616/59869 (19.4%) | Rate: 51.1 files/sec | Elapsed: 227.5s | ETA: 944.9s
# Progress: 11648/59869 (19.5%) | Rate: 51.1 files/sec | Elapsed: 228.1s | ETA: 944.1s
# Progress: 11680/59869 (19.5%) | Rate: 51.1 files/sec | Elapsed: 228.6s | ETA: 943.3s
# Progress: 11712/59869 (19.6%) | Rate: 51.1 files/sec | Elapsed: 229.2s | ETA: 942.4s
# Progress: 11744/59869 (19.6%) | Rate: 51.1 files/sec | Elapsed: 229.9s | ETA: 942.2s
# Progress: 11776/59869 (19.7%) | Rate: 51.1 files/sec | Elapsed: 230.5s | ETA: 941.3s
# Progress: 11808/59869 (19.7%) | Rate: 51.1 files/sec | Elapsed: 231.0s | ETA: 940.4s
# Progress: 11840/59869 (19.8%) | Rate: 51.1 files/sec | Elapsed: 231.7s | ETA: 939.8s
# Progress: 11872/59869 (19.8%) | Rate: 51.1 files/sec | Elapsed: 232.3s | ETA: 939.0s
# Progress: 11904/59869 (19.9%) | Rate: 51.1 files/sec | Elapsed: 233.0s | ETA: 938.7s
# Progress: 11936/59869 (19.9%) | Rate: 51.1 files/sec | Elapsed: 233.6s | ETA: 938.1s
# Progress: 11968/59869 (20.0%) | Rate: 51.1 files/sec | Elapsed: 234.2s | ETA: 937.3s
# Progress: 12000/59869 (20.0%) | Rate: 51.1 files/sec | Elapsed: 234.8s | ETA: 936.5s
# Progress: 12032/59869 (20.1%) | Rate: 51.1 files/sec | Elapsed: 235.4s | ETA: 936.0s
# Progress: 12064/59869 (20.2%) | Rate: 51.1 files/sec | Elapsed: 236.3s | ETA: 936.3s
# Progress: 12096/59869 (20.2%) | Rate: 51.1 files/sec | Elapsed: 236.9s | ETA: 935.6s
# Progress: 12128/59869 (20.3%) | Rate: 51.1 files/sec | Elapsed: 237.4s | ETA: 934.6s
# Progress: 12160/59869 (20.3%) | Rate: 51.1 files/sec | Elapsed: 238.0s | ETA: 933.9s
# Progress: 12192/59869 (20.4%) | Rate: 51.1 files/sec | Elapsed: 238.6s | ETA: 933.1s
# Progress: 12224/59869 (20.4%) | Rate: 51.1 files/sec | Elapsed: 239.3s | ETA: 932.8s
# Progress: 12256/59869 (20.5%) | Rate: 51.1 files/sec | Elapsed: 239.9s | ETA: 932.0s
# Progress: 12288/59869 (20.5%) | Rate: 51.1 files/sec | Elapsed: 240.5s | ETA: 931.2s
# Progress: 12320/59869 (20.6%) | Rate: 51.1 files/sec | Elapsed: 241.1s | ETA: 930.5s
# Progress: 12352/59869 (20.6%) | Rate: 51.1 files/sec | Elapsed: 241.7s | ETA: 929.7s
# Progress: 12384/59869 (20.7%) | Rate: 51.1 files/sec | Elapsed: 242.4s | ETA: 929.4s
# Progress: 12416/59869 (20.7%) | Rate: 51.1 files/sec | Elapsed: 243.0s | ETA: 928.6s
# Progress: 12448/59869 (20.8%) | Rate: 51.1 files/sec | Elapsed: 243.5s | ETA: 927.8s
# Progress: 12480/59869 (20.8%) | Rate: 51.1 files/sec | Elapsed: 244.1s | ETA: 926.9s
# Progress: 12512/59869 (20.9%) | Rate: 51.1 files/sec | Elapsed: 244.6s | ETA: 926.0s
# Progress: 12544/59869 (21.0%) | Rate: 51.1 files/sec | Elapsed: 245.3s | ETA: 925.5s
# Progress: 12576/59869 (21.0%) | Rate: 51.1 files/sec | Elapsed: 245.9s | ETA: 924.7s
# Progress: 12608/59869 (21.1%) | Rate: 51.1 files/sec | Elapsed: 246.6s | ETA: 924.3s
# Progress: 12640/59869 (21.1%) | Rate: 51.1 files/sec | Elapsed: 247.2s | ETA: 923.5s
# Progress: 12672/59869 (21.2%) | Rate: 51.1 files/sec | Elapsed: 247.8s | ETA: 922.8s
# Progress: 12704/59869 (21.2%) | Rate: 51.1 files/sec | Elapsed: 248.5s | ETA: 922.4s
# Progress: 12736/59869 (21.3%) | Rate: 51.1 files/sec | Elapsed: 249.0s | ETA: 921.7s
# Progress: 12768/59869 (21.3%) | Rate: 51.1 files/sec | Elapsed: 249.7s | ETA: 921.0s
# Progress: 12800/59869 (21.4%) | Rate: 51.2 files/sec | Elapsed: 250.2s | ETA: 920.1s
# Progress: 12832/59869 (21.4%) | Rate: 51.2 files/sec | Elapsed: 250.8s | ETA: 919.2s
# Progress: 12864/59869 (21.5%) | Rate: 51.1 files/sec | Elapsed: 251.5s | ETA: 919.0s
# Progress: 12896/59869 (21.5%) | Rate: 51.1 files/sec | Elapsed: 252.2s | ETA: 918.6s
# Progress: 12928/59869 (21.6%) | Rate: 51.1 files/sec | Elapsed: 252.8s | ETA: 917.8s
# Progress: 12960/59869 (21.6%) | Rate: 51.2 files/sec | Elapsed: 253.3s | ETA: 916.9s
# Progress: 12992/59869 (21.7%) | Rate: 51.2 files/sec | Elapsed: 253.9s | ETA: 916.3s
# Progress: 13024/59869 (21.8%) | Rate: 51.1 files/sec | Elapsed: 254.6s | ETA: 915.9s
# Progress: 13056/59869 (21.8%) | Rate: 51.1 files/sec | Elapsed: 255.3s | ETA: 915.3s
# Progress: 13088/59869 (21.9%) | Rate: 51.2 files/sec | Elapsed: 255.8s | ETA: 914.4s
# Progress: 13120/59869 (21.9%) | Rate: 51.2 files/sec | Elapsed: 256.4s | ETA: 913.7s
# Progress: 13152/59869 (22.0%) | Rate: 51.2 files/sec | Elapsed: 257.0s | ETA: 912.9s
# Progress: 13184/59869 (22.0%) | Rate: 51.1 files/sec | Elapsed: 257.9s | ETA: 913.2s
# Progress: 13216/59869 (22.1%) | Rate: 51.1 files/sec | Elapsed: 258.5s | ETA: 912.4s
# Progress: 13248/59869 (22.1%) | Rate: 51.1 files/sec | Elapsed: 259.1s | ETA: 911.8s
# Progress: 13280/59869 (22.2%) | Rate: 51.1 files/sec | Elapsed: 259.7s | ETA: 911.1s
# Progress: 13312/59869 (22.2%) | Rate: 51.1 files/sec | Elapsed: 260.3s | ETA: 910.3s
# Progress: 13344/59869 (22.3%) | Rate: 51.1 files/sec | Elapsed: 260.9s | ETA: 909.8s
# Progress: 13376/59869 (22.3%) | Rate: 51.1 files/sec | Elapsed: 261.6s | ETA: 909.3s
# Progress: 13408/59869 (22.4%) | Rate: 51.1 files/sec | Elapsed: 262.6s | ETA: 909.9s
# Progress: 13440/59869 (22.4%) | Rate: 51.0 files/sec | Elapsed: 263.3s | ETA: 909.7s
# Progress: 13472/59869 (22.5%) | Rate: 51.0 files/sec | Elapsed: 263.9s | ETA: 909.0s
# Progress: 13504/59869 (22.6%) | Rate: 51.0 files/sec | Elapsed: 264.7s | ETA: 908.8s
# Progress: 13536/59869 (22.6%) | Rate: 51.0 files/sec | Elapsed: 265.4s | ETA: 908.4s
# Progress: 13568/59869 (22.7%) | Rate: 51.0 files/sec | Elapsed: 265.9s | ETA: 907.5s
# Progress: 13600/59869 (22.7%) | Rate: 51.0 files/sec | Elapsed: 266.5s | ETA: 906.7s
# Progress: 13632/59869 (22.8%) | Rate: 51.0 files/sec | Elapsed: 267.1s | ETA: 905.9s
# Progress: 13664/59869 (22.8%) | Rate: 51.0 files/sec | Elapsed: 267.9s | ETA: 906.0s
# Progress: 13696/59869 (22.9%) | Rate: 51.0 files/sec | Elapsed: 268.5s | ETA: 905.3s
# Progress: 13728/59869 (22.9%) | Rate: 51.0 files/sec | Elapsed: 269.1s | ETA: 904.5s
# Progress: 13760/59869 (23.0%) | Rate: 51.0 files/sec | Elapsed: 269.8s | ETA: 904.2s
# Progress: 13792/59869 (23.0%) | Rate: 51.0 files/sec | Elapsed: 270.4s | ETA: 903.3s
# Progress: 13824/59869 (23.1%) | Rate: 51.0 files/sec | Elapsed: 271.1s | ETA: 903.0s
# Progress: 13856/59869 (23.1%) | Rate: 51.0 files/sec | Elapsed: 271.7s | ETA: 902.2s
# Progress: 13888/59869 (23.2%) | Rate: 51.0 files/sec | Elapsed: 272.2s | ETA: 901.4s
# Progress: 13920/59869 (23.3%) | Rate: 51.0 files/sec | Elapsed: 272.8s | ETA: 900.5s
# Progress: 13952/59869 (23.3%) | Rate: 51.0 files/sec | Elapsed: 273.4s | ETA: 899.9s
# Progress: 13984/59869 (23.4%) | Rate: 51.0 files/sec | Elapsed: 274.2s | ETA: 899.6s
# Progress: 14016/59869 (23.4%) | Rate: 51.0 files/sec | Elapsed: 274.8s | ETA: 898.9s
# Progress: 14048/59869 (23.5%) | Rate: 51.0 files/sec | Elapsed: 275.4s | ETA: 898.1s
# Progress: 14080/59869 (23.5%) | Rate: 51.0 files/sec | Elapsed: 276.0s | ETA: 897.5s
# Progress: 14112/59869 (23.6%) | Rate: 51.0 files/sec | Elapsed: 276.8s | ETA: 897.5s
# Progress: 14144/59869 (23.6%) | Rate: 50.9 files/sec | Elapsed: 277.7s | ETA: 897.8s
# Progress: 14176/59869 (23.7%) | Rate: 50.9 files/sec | Elapsed: 278.4s | ETA: 897.4s
# Progress: 14208/59869 (23.7%) | Rate: 50.9 files/sec | Elapsed: 279.2s | ETA: 897.2s
# Progress: 14240/59869 (23.8%) | Rate: 50.9 files/sec | Elapsed: 279.9s | ETA: 897.0s
# Progress: 14272/59869 (23.8%) | Rate: 50.8 files/sec | Elapsed: 280.7s | ETA: 896.8s
# Progress: 14304/59869 (23.9%) | Rate: 50.8 files/sec | Elapsed: 281.4s | ETA: 896.4s
# Progress: 14336/59869 (23.9%) | Rate: 50.8 files/sec | Elapsed: 282.0s | ETA: 895.6s
# Progress: 14368/59869 (24.0%) | Rate: 50.9 files/sec | Elapsed: 282.5s | ETA: 894.8s
# Progress: 14400/59869 (24.1%) | Rate: 50.9 files/sec | Elapsed: 283.1s | ETA: 893.9s
# Progress: 14432/59869 (24.1%) | Rate: 50.9 files/sec | Elapsed: 283.7s | ETA: 893.2s
# Progress: 14464/59869 (24.2%) | Rate: 50.9 files/sec | Elapsed: 284.4s | ETA: 892.6s
# Progress: 14496/59869 (24.2%) | Rate: 50.9 files/sec | Elapsed: 285.0s | ETA: 891.9s
# Progress: 14528/59869 (24.3%) | Rate: 50.9 files/sec | Elapsed: 285.6s | ETA: 891.3s
# Progress: 14560/59869 (24.3%) | Rate: 50.9 files/sec | Elapsed: 286.1s | ETA: 890.4s
# Progress: 14592/59869 (24.4%) | Rate: 50.9 files/sec | Elapsed: 286.7s | ETA: 889.7s
# Progress: 14624/59869 (24.4%) | Rate: 50.9 files/sec | Elapsed: 287.5s | ETA: 889.5s
# Progress: 14656/59869 (24.5%) | Rate: 50.9 files/sec | Elapsed: 288.1s | ETA: 888.7s
# Progress: 14688/59869 (24.5%) | Rate: 50.9 files/sec | Elapsed: 288.6s | ETA: 887.8s
# Progress: 14720/59869 (24.6%) | Rate: 50.9 files/sec | Elapsed: 289.3s | ETA: 887.2s
# Progress: 14752/59869 (24.6%) | Rate: 50.9 files/sec | Elapsed: 289.9s | ETA: 886.5s
# Progress: 14784/59869 (24.7%) | Rate: 50.9 files/sec | Elapsed: 290.5s | ETA: 886.0s
# Progress: 14816/59869 (24.7%) | Rate: 50.9 files/sec | Elapsed: 291.2s | ETA: 885.3s
# Progress: 14848/59869 (24.8%) | Rate: 50.9 files/sec | Elapsed: 291.7s | ETA: 884.5s
# Progress: 14880/59869 (24.9%) | Rate: 50.9 files/sec | Elapsed: 292.3s | ETA: 883.7s
# Progress: 14912/59869 (24.9%) | Rate: 50.9 files/sec | Elapsed: 292.9s | ETA: 882.9s
# Progress: 14944/59869 (25.0%) | Rate: 50.9 files/sec | Elapsed: 293.6s | ETA: 882.6s
# Progress: 14976/59869 (25.0%) | Rate: 50.9 files/sec | Elapsed: 294.2s | ETA: 882.0s
# Progress: 15008/59869 (25.1%) | Rate: 50.9 files/sec | Elapsed: 294.8s | ETA: 881.3s
# Progress: 15040/59869 (25.1%) | Rate: 50.9 files/sec | Elapsed: 295.5s | ETA: 880.7s
# Progress: 15072/59869 (25.2%) | Rate: 50.9 files/sec | Elapsed: 296.1s | ETA: 880.0s
# Progress: 15104/59869 (25.2%) | Rate: 50.9 files/sec | Elapsed: 296.8s | ETA: 879.6s
# Progress: 15136/59869 (25.3%) | Rate: 50.9 files/sec | Elapsed: 297.4s | ETA: 878.9s
# Progress: 15168/59869 (25.3%) | Rate: 50.9 files/sec | Elapsed: 298.0s | ETA: 878.2s
# Progress: 15200/59869 (25.4%) | Rate: 50.9 files/sec | Elapsed: 298.6s | ETA: 877.6s
# Progress: 15232/59869 (25.4%) | Rate: 50.9 files/sec | Elapsed: 299.3s | ETA: 877.1s
# Progress: 15264/59869 (25.5%) | Rate: 50.9 files/sec | Elapsed: 300.1s | ETA: 876.8s
# Progress: 15296/59869 (25.5%) | Rate: 50.9 files/sec | Elapsed: 300.7s | ETA: 876.3s
# Progress: 15328/59869 (25.6%) | Rate: 50.9 files/sec | Elapsed: 301.3s | ETA: 875.5s
# Progress: 15360/59869 (25.7%) | Rate: 50.9 files/sec | Elapsed: 301.8s | ETA: 874.7s
# Progress: 15392/59869 (25.7%) | Rate: 50.9 files/sec | Elapsed: 302.5s | ETA: 874.0s
# Progress: 15424/59869 (25.8%) | Rate: 50.9 files/sec | Elapsed: 303.2s | ETA: 873.5s
# Progress: 15456/59869 (25.8%) | Rate: 50.9 files/sec | Elapsed: 303.7s | ETA: 872.8s
# Progress: 15488/59869 (25.9%) | Rate: 50.9 files/sec | Elapsed: 304.4s | ETA: 872.4s
# Progress: 15520/59869 (25.9%) | Rate: 50.9 files/sec | Elapsed: 305.0s | ETA: 871.5s
# Progress: 15552/59869 (26.0%) | Rate: 50.9 files/sec | Elapsed: 305.6s | ETA: 870.7s
# Progress: 15584/59869 (26.0%) | Rate: 50.9 files/sec | Elapsed: 306.3s | ETA: 870.3s
# Progress: 15616/59869 (26.1%) | Rate: 50.9 files/sec | Elapsed: 306.9s | ETA: 869.7s
# Progress: 15648/59869 (26.1%) | Rate: 50.9 files/sec | Elapsed: 307.5s | ETA: 869.0s
# Progress: 15680/59869 (26.2%) | Rate: 50.9 files/sec | Elapsed: 308.1s | ETA: 868.2s
# Progress: 15712/59869 (26.2%) | Rate: 50.9 files/sec | Elapsed: 308.6s | ETA: 867.3s
# Progress: 15744/59869 (26.3%) | Rate: 50.9 files/sec | Elapsed: 309.3s | ETA: 867.0s
# Progress: 15776/59869 (26.4%) | Rate: 50.9 files/sec | Elapsed: 309.9s | ETA: 866.2s
# Progress: 15808/59869 (26.4%) | Rate: 50.9 files/sec | Elapsed: 310.5s | ETA: 865.4s
# Progress: 15840/59869 (26.5%) | Rate: 50.9 files/sec | Elapsed: 311.1s | ETA: 864.7s
# Progress: 15872/59869 (26.5%) | Rate: 50.9 files/sec | Elapsed: 311.6s | ETA: 863.8s
# Progress: 15904/59869 (26.6%) | Rate: 50.9 files/sec | Elapsed: 312.3s | ETA: 863.5s
# Progress: 15936/59869 (26.6%) | Rate: 50.9 files/sec | Elapsed: 312.9s | ETA: 862.7s
# Progress: 15968/59869 (26.7%) | Rate: 50.9 files/sec | Elapsed: 313.5s | ETA: 861.9s
# Progress: 16000/59869 (26.7%) | Rate: 50.9 files/sec | Elapsed: 314.1s | ETA: 861.2s
# Progress: 16032/59869 (26.8%) | Rate: 51.0 files/sec | Elapsed: 314.7s | ETA: 860.4s
# Progress: 16064/59869 (26.8%) | Rate: 50.9 files/sec | Elapsed: 315.4s | ETA: 860.2s
# Progress: 16096/59869 (26.9%) | Rate: 50.9 files/sec | Elapsed: 316.0s | ETA: 859.4s
# Progress: 16128/59869 (26.9%) | Rate: 50.9 files/sec | Elapsed: 316.6s | ETA: 858.6s
# Progress: 16160/59869 (27.0%) | Rate: 51.0 files/sec | Elapsed: 317.1s | ETA: 857.7s
# Progress: 16192/59869 (27.0%) | Rate: 51.0 files/sec | Elapsed: 317.8s | ETA: 857.1s
# Progress: 16224/59869 (27.1%) | Rate: 50.9 files/sec | Elapsed: 318.5s | ETA: 856.9s
# Progress: 16256/59869 (27.2%) | Rate: 50.9 files/sec | Elapsed: 319.1s | ETA: 856.1s
# Progress: 16288/59869 (27.2%) | Rate: 50.9 files/sec | Elapsed: 319.7s | ETA: 855.4s
# Progress: 16320/59869 (27.3%) | Rate: 50.9 files/sec | Elapsed: 320.3s | ETA: 854.8s
# Progress: 16352/59869 (27.3%) | Rate: 51.0 files/sec | Elapsed: 320.9s | ETA: 854.0s
# Progress: 16384/59869 (27.4%) | Rate: 50.9 files/sec | Elapsed: 321.7s | ETA: 853.8s
# Progress: 16416/59869 (27.4%) | Rate: 50.9 files/sec | Elapsed: 322.2s | ETA: 852.9s
# Progress: 16448/59869 (27.5%) | Rate: 51.0 files/sec | Elapsed: 322.8s | ETA: 852.2s
# Progress: 16480/59869 (27.5%) | Rate: 51.0 files/sec | Elapsed: 323.4s | ETA: 851.4s
# Progress: 16512/59869 (27.6%) | Rate: 51.0 files/sec | Elapsed: 324.0s | ETA: 850.8s
# Progress: 16544/59869 (27.6%) | Rate: 50.9 files/sec | Elapsed: 324.8s | ETA: 850.5s
# Progress: 16576/59869 (27.7%) | Rate: 50.9 files/sec | Elapsed: 325.5s | ETA: 850.3s
# Progress: 16608/59869 (27.7%) | Rate: 50.9 files/sec | Elapsed: 326.2s | ETA: 849.7s
# Progress: 16640/59869 (27.8%) | Rate: 50.9 files/sec | Elapsed: 326.8s | ETA: 849.0s
# Progress: 16672/59869 (27.8%) | Rate: 50.9 files/sec | Elapsed: 327.4s | ETA: 848.3s
# Progress: 16704/59869 (27.9%) | Rate: 50.9 files/sec | Elapsed: 328.1s | ETA: 847.9s
# Progress: 16736/59869 (28.0%) | Rate: 50.9 files/sec | Elapsed: 328.7s | ETA: 847.0s
# Progress: 16768/59869 (28.0%) | Rate: 50.9 files/sec | Elapsed: 329.2s | ETA: 846.3s
# Progress: 16800/59869 (28.1%) | Rate: 50.9 files/sec | Elapsed: 329.8s | ETA: 845.5s
# Progress: 16832/59869 (28.1%) | Rate: 50.9 files/sec | Elapsed: 330.4s | ETA: 844.8s
# Progress: 16864/59869 (28.2%) | Rate: 50.9 files/sec | Elapsed: 331.1s | ETA: 844.3s
# Progress: 16896/59869 (28.2%) | Rate: 50.9 files/sec | Elapsed: 331.7s | ETA: 843.7s
# Progress: 16928/59869 (28.3%) | Rate: 50.9 files/sec | Elapsed: 332.3s | ETA: 843.0s
# Progress: 16960/59869 (28.3%) | Rate: 51.0 files/sec | Elapsed: 332.9s | ETA: 842.1s
# Progress: 16992/59869 (28.4%) | Rate: 51.0 files/sec | Elapsed: 333.5s | ETA: 841.5s
# Progress: 17024/59869 (28.4%) | Rate: 50.9 files/sec | Elapsed: 334.2s | ETA: 841.2s
# Progress: 17056/59869 (28.5%) | Rate: 50.9 files/sec | Elapsed: 334.8s | ETA: 840.5s
# Progress: 17088/59869 (28.5%) | Rate: 50.9 files/sec | Elapsed: 335.5s | ETA: 839.8s
# Progress: 17120/59869 (28.6%) | Rate: 50.9 files/sec | Elapsed: 336.1s | ETA: 839.2s
# Progress: 17152/59869 (28.6%) | Rate: 50.9 files/sec | Elapsed: 336.7s | ETA: 838.5s
# Progress: 17184/59869 (28.7%) | Rate: 50.9 files/sec | Elapsed: 337.4s | ETA: 838.1s
# Progress: 17216/59869 (28.8%) | Rate: 50.9 files/sec | Elapsed: 338.1s | ETA: 837.6s
# Progress: 17248/59869 (28.8%) | Rate: 50.9 files/sec | Elapsed: 338.6s | ETA: 836.8s
# Progress: 17280/59869 (28.9%) | Rate: 50.9 files/sec | Elapsed: 339.2s | ETA: 836.1s
# Progress: 17312/59869 (28.9%) | Rate: 50.9 files/sec | Elapsed: 339.8s | ETA: 835.4s
# Progress: 17344/59869 (29.0%) | Rate: 50.9 files/sec | Elapsed: 340.5s | ETA: 834.8s
# Progress: 17376/59869 (29.0%) | Rate: 50.9 files/sec | Elapsed: 341.1s | ETA: 834.1s
# Progress: 17408/59869 (29.1%) | Rate: 51.0 files/sec | Elapsed: 341.7s | ETA: 833.4s
# Progress: 17440/59869 (29.1%) | Rate: 51.0 files/sec | Elapsed: 342.3s | ETA: 832.7s
# Progress: 17472/59869 (29.2%) | Rate: 51.0 files/sec | Elapsed: 342.9s | ETA: 832.0s
# Progress: 17504/59869 (29.2%) | Rate: 50.9 files/sec | Elapsed: 343.6s | ETA: 831.6s
# Progress: 17536/59869 (29.3%) | Rate: 50.9 files/sec | Elapsed: 344.2s | ETA: 831.0s
# Progress: 17568/59869 (29.3%) | Rate: 50.9 files/sec | Elapsed: 344.8s | ETA: 830.3s
# Progress: 17600/59869 (29.4%) | Rate: 51.0 files/sec | Elapsed: 345.4s | ETA: 829.5s
# Progress: 17632/59869 (29.5%) | Rate: 51.0 files/sec | Elapsed: 346.0s | ETA: 828.7s
# Progress: 17664/59869 (29.5%) | Rate: 50.9 files/sec | Elapsed: 346.8s | ETA: 828.6s
# Progress: 17696/59869 (29.6%) | Rate: 50.9 files/sec | Elapsed: 347.4s | ETA: 827.9s
# Progress: 17728/59869 (29.6%) | Rate: 51.0 files/sec | Elapsed: 347.9s | ETA: 827.1s
# Progress: 17760/59869 (29.7%) | Rate: 51.0 files/sec | Elapsed: 348.6s | ETA: 826.4s
# Progress: 17792/59869 (29.7%) | Rate: 51.0 files/sec | Elapsed: 349.1s | ETA: 825.7s
# Progress: 17824/59869 (29.8%) | Rate: 50.9 files/sec | Elapsed: 349.8s | ETA: 825.2s
# Progress: 17856/59869 (29.8%) | Rate: 51.0 files/sec | Elapsed: 350.4s | ETA: 824.5s
# Progress: 17888/59869 (29.9%) | Rate: 51.0 files/sec | Elapsed: 351.1s | ETA: 823.9s
# Progress: 17920/59869 (29.9%) | Rate: 51.0 files/sec | Elapsed: 351.7s | ETA: 823.2s
# Progress: 17952/59869 (30.0%) | Rate: 51.0 files/sec | Elapsed: 352.3s | ETA: 822.6s
# Progress: 17984/59869 (30.0%) | Rate: 50.9 files/sec | Elapsed: 353.0s | ETA: 822.1s
# Progress: 18016/59869 (30.1%) | Rate: 51.0 files/sec | Elapsed: 353.6s | ETA: 821.4s
# Progress: 18048/59869 (30.1%) | Rate: 51.0 files/sec | Elapsed: 354.2s | ETA: 820.7s
# ...
# Progress: 53984/59869 (90.2%) | Rate: 49.9 files/sec | Elapsed: 1081.7s | ETA: 117.9s
# Progress: 54016/59869 (90.2%) | Rate: 49.9 files/sec | Elapsed: 1082.3s | ETA: 117.3s
# Progress: 54048/59869 (90.3%) | Rate: 49.9 files/sec | Elapsed: 1082.9s | ETA: 116.6s
# Progress: 54080/59869 (90.3%) | Rate: 49.9 files/sec | Elapsed: 1083.5s | ETA: 116.0s
# Progress: 54112/59869 (90.4%) | Rate: 49.9 files/sec | Elapsed: 1084.2s | ETA: 115.3s
# Progress: 54144/59869 (90.4%) | Rate: 49.9 files/sec | Elapsed: 1084.9s | ETA: 114.7s
# Progress: 54176/59869 (90.5%) | Rate: 49.9 files/sec | Elapsed: 1085.6s | ETA: 114.1s
# Progress: 54208/59869 (90.5%) | Rate: 49.9 files/sec | Elapsed: 1086.2s | ETA: 113.4s
# Progress: 54240/59869 (90.6%) | Rate: 49.9 files/sec | Elapsed: 1086.8s | ETA: 112.8s
# Progress: 54272/59869 (90.7%) | Rate: 49.9 files/sec | Elapsed: 1087.4s | ETA: 112.1s
# Progress: 54304/59869 (90.7%) | Rate: 49.9 files/sec | Elapsed: 1088.2s | ETA: 111.5s
# Progress: 54336/59869 (90.8%) | Rate: 49.9 files/sec | Elapsed: 1088.9s | ETA: 110.9s
# Progress: 54368/59869 (90.8%) | Rate: 49.9 files/sec | Elapsed: 1089.6s | ETA: 110.2s
# Progress: 54400/59869 (90.9%) | Rate: 49.9 files/sec | Elapsed: 1090.2s | ETA: 109.6s
# Progress: 54432/59869 (90.9%) | Rate: 49.9 files/sec | Elapsed: 1090.8s | ETA: 109.0s
# Progress: 54464/59869 (91.0%) | Rate: 49.9 files/sec | Elapsed: 1091.5s | ETA: 108.3s
# Progress: 54496/59869 (91.0%) | Rate: 49.9 files/sec | Elapsed: 1092.2s | ETA: 107.7s
# Progress: 54528/59869 (91.1%) | Rate: 49.9 files/sec | Elapsed: 1092.8s | ETA: 107.0s
# Progress: 54560/59869 (91.1%) | Rate: 49.9 files/sec | Elapsed: 1093.4s | ETA: 106.4s
# Progress: 54592/59869 (91.2%) | Rate: 49.9 files/sec | Elapsed: 1094.0s | ETA: 105.7s
# Progress: 54624/59869 (91.2%) | Rate: 49.9 files/sec | Elapsed: 1095.0s | ETA: 105.1s
# Progress: 54656/59869 (91.3%) | Rate: 49.9 files/sec | Elapsed: 1095.6s | ETA: 104.5s
# Progress: 54688/59869 (91.3%) | Rate: 49.9 files/sec | Elapsed: 1096.2s | ETA: 103.9s
# Progress: 54720/59869 (91.4%) | Rate: 49.9 files/sec | Elapsed: 1096.8s | ETA: 103.2s
# Progress: 54752/59869 (91.5%) | Rate: 49.9 files/sec | Elapsed: 1097.4s | ETA: 102.6s
# Progress: 54784/59869 (91.5%) | Rate: 49.9 files/sec | Elapsed: 1098.2s | ETA: 101.9s
# Progress: 54816/59869 (91.6%) | Rate: 49.9 files/sec | Elapsed: 1098.8s | ETA: 101.3s
# Progress: 54848/59869 (91.6%) | Rate: 49.9 files/sec | Elapsed: 1099.5s | ETA: 100.7s
# Progress: 54880/59869 (91.7%) | Rate: 49.9 files/sec | Elapsed: 1100.1s | ETA: 100.0s
# Progress: 54912/59869 (91.7%) | Rate: 49.9 files/sec | Elapsed: 1100.6s | ETA: 99.4s
# Progress: 54944/59869 (91.8%) | Rate: 49.9 files/sec | Elapsed: 1101.5s | ETA: 98.7s
# Progress: 54976/59869 (91.8%) | Rate: 49.9 files/sec | Elapsed: 1102.1s | ETA: 98.1s
# Progress: 55008/59869 (91.9%) | Rate: 49.9 files/sec | Elapsed: 1102.7s | ETA: 97.4s
# Progress: 55040/59869 (91.9%) | Rate: 49.9 files/sec | Elapsed: 1103.3s | ETA: 96.8s
# Progress: 55072/59869 (92.0%) | Rate: 49.9 files/sec | Elapsed: 1103.9s | ETA: 96.2s
# Progress: 55104/59869 (92.0%) | Rate: 49.9 files/sec | Elapsed: 1104.7s | ETA: 95.5s
# Progress: 55136/59869 (92.1%) | Rate: 49.9 files/sec | Elapsed: 1105.3s | ETA: 94.9s
# Progress: 55168/59869 (92.1%) | Rate: 49.9 files/sec | Elapsed: 1105.9s | ETA: 94.2s
# Progress: 55200/59869 (92.2%) | Rate: 49.9 files/sec | Elapsed: 1106.5s | ETA: 93.6s
# Progress: 55232/59869 (92.3%) | Rate: 49.9 files/sec | Elapsed: 1107.1s | ETA: 93.0s
# Progress: 55264/59869 (92.3%) | Rate: 49.9 files/sec | Elapsed: 1107.9s | ETA: 92.3s
# Progress: 55296/59869 (92.4%) | Rate: 49.9 files/sec | Elapsed: 1108.6s | ETA: 91.7s
# Progress: 55328/59869 (92.4%) | Rate: 49.9 files/sec | Elapsed: 1109.2s | ETA: 91.0s
# Progress: 55360/59869 (92.5%) | Rate: 49.9 files/sec | Elapsed: 1109.9s | ETA: 90.4s
# Progress: 55392/59869 (92.5%) | Rate: 49.9 files/sec | Elapsed: 1110.5s | ETA: 89.8s
# Progress: 55424/59869 (92.6%) | Rate: 49.9 files/sec | Elapsed: 1111.3s | ETA: 89.1s
# Progress: 55456/59869 (92.6%) | Rate: 49.9 files/sec | Elapsed: 1111.9s | ETA: 88.5s
# Progress: 55488/59869 (92.7%) | Rate: 49.9 files/sec | Elapsed: 1112.5s | ETA: 87.8s
# Progress: 55520/59869 (92.7%) | Rate: 49.9 files/sec | Elapsed: 1113.1s | ETA: 87.2s
# Progress: 55552/59869 (92.8%) | Rate: 49.9 files/sec | Elapsed: 1113.7s | ETA: 86.5s
# Progress: 55584/59869 (92.8%) | Rate: 49.9 files/sec | Elapsed: 1114.5s | ETA: 85.9s
# Progress: 55616/59869 (92.9%) | Rate: 49.9 files/sec | Elapsed: 1115.1s | ETA: 85.3s
# Progress: 55648/59869 (92.9%) | Rate: 49.9 files/sec | Elapsed: 1115.7s | ETA: 84.6s
# Progress: 55680/59869 (93.0%) | Rate: 49.9 files/sec | Elapsed: 1116.3s | ETA: 84.0s
# Progress: 55712/59869 (93.1%) | Rate: 49.9 files/sec | Elapsed: 1117.0s | ETA: 83.3s
# Progress: 55744/59869 (93.1%) | Rate: 49.9 files/sec | Elapsed: 1117.8s | ETA: 82.7s
# Progress: 55776/59869 (93.2%) | Rate: 49.9 files/sec | Elapsed: 1118.4s | ETA: 82.1s
# Progress: 55808/59869 (93.2%) | Rate: 49.9 files/sec | Elapsed: 1119.0s | ETA: 81.4s
# Progress: 55840/59869 (93.3%) | Rate: 49.9 files/sec | Elapsed: 1119.7s | ETA: 80.8s
# Progress: 55872/59869 (93.3%) | Rate: 49.9 files/sec | Elapsed: 1120.3s | ETA: 80.1s
# Progress: 55904/59869 (93.4%) | Rate: 49.9 files/sec | Elapsed: 1121.2s | ETA: 79.5s
# Progress: 55936/59869 (93.4%) | Rate: 49.9 files/sec | Elapsed: 1121.9s | ETA: 78.9s
# Progress: 55968/59869 (93.5%) | Rate: 49.9 files/sec | Elapsed: 1122.5s | ETA: 78.2s
# Progress: 56000/59869 (93.5%) | Rate: 49.9 files/sec | Elapsed: 1123.1s | ETA: 77.6s
# Progress: 56032/59869 (93.6%) | Rate: 49.9 files/sec | Elapsed: 1123.8s | ETA: 77.0s
# Progress: 56064/59869 (93.6%) | Rate: 49.9 files/sec | Elapsed: 1124.6s | ETA: 76.3s
# Progress: 56096/59869 (93.7%) | Rate: 49.9 files/sec | Elapsed: 1125.3s | ETA: 75.7s
# Progress: 56128/59869 (93.8%) | Rate: 49.9 files/sec | Elapsed: 1125.9s | ETA: 75.0s
# Progress: 56160/59869 (93.8%) | Rate: 49.9 files/sec | Elapsed: 1126.5s | ETA: 74.4s
# Progress: 56192/59869 (93.9%) | Rate: 49.9 files/sec | Elapsed: 1127.1s | ETA: 73.8s
# Progress: 56224/59869 (93.9%) | Rate: 49.9 files/sec | Elapsed: 1127.8s | ETA: 73.1s
# Progress: 56256/59869 (94.0%) | Rate: 49.9 files/sec | Elapsed: 1128.4s | ETA: 72.5s
# Progress: 56288/59869 (94.0%) | Rate: 49.9 files/sec | Elapsed: 1129.1s | ETA: 71.8s
# Progress: 56320/59869 (94.1%) | Rate: 49.9 files/sec | Elapsed: 1129.7s | ETA: 71.2s
# Progress: 56352/59869 (94.1%) | Rate: 49.8 files/sec | Elapsed: 1130.4s | ETA: 70.6s
# Progress: 56384/59869 (94.2%) | Rate: 49.8 files/sec | Elapsed: 1131.2s | ETA: 69.9s
# Progress: 56416/59869 (94.2%) | Rate: 49.8 files/sec | Elapsed: 1131.8s | ETA: 69.3s
# Progress: 56448/59869 (94.3%) | Rate: 49.8 files/sec | Elapsed: 1132.4s | ETA: 68.6s
# Progress: 56480/59869 (94.3%) | Rate: 49.9 files/sec | Elapsed: 1133.0s | ETA: 68.0s
# Progress: 56512/59869 (94.4%) | Rate: 49.9 files/sec | Elapsed: 1133.6s | ETA: 67.3s
# Progress: 56544/59869 (94.4%) | Rate: 49.8 files/sec | Elapsed: 1134.4s | ETA: 66.7s
# Progress: 56576/59869 (94.5%) | Rate: 49.8 files/sec | Elapsed: 1135.1s | ETA: 66.1s
# Progress: 56608/59869 (94.6%) | Rate: 49.8 files/sec | Elapsed: 1135.9s | ETA: 65.4s
# Progress: 56640/59869 (94.6%) | Rate: 49.8 files/sec | Elapsed: 1136.5s | ETA: 64.8s
# Progress: 56672/59869 (94.7%) | Rate: 49.8 files/sec | Elapsed: 1137.2s | ETA: 64.1s
# Progress: 56704/59869 (94.7%) | Rate: 49.8 files/sec | Elapsed: 1138.0s | ETA: 63.5s
# Progress: 56736/59869 (94.8%) | Rate: 49.8 files/sec | Elapsed: 1138.6s | ETA: 62.9s
# Progress: 56768/59869 (94.8%) | Rate: 49.8 files/sec | Elapsed: 1139.2s | ETA: 62.2s
# Progress: 56800/59869 (94.9%) | Rate: 49.8 files/sec | Elapsed: 1139.8s | ETA: 61.6s
# Progress: 56832/59869 (94.9%) | Rate: 49.8 files/sec | Elapsed: 1140.5s | ETA: 60.9s
# Progress: 56864/59869 (95.0%) | Rate: 49.8 files/sec | Elapsed: 1141.2s | ETA: 60.3s
# Progress: 56896/59869 (95.0%) | Rate: 49.8 files/sec | Elapsed: 1141.8s | ETA: 59.7s
# Progress: 56928/59869 (95.1%) | Rate: 49.8 files/sec | Elapsed: 1142.4s | ETA: 59.0s
# Progress: 56960/59869 (95.1%) | Rate: 49.8 files/sec | Elapsed: 1143.1s | ETA: 58.4s
# Progress: 56992/59869 (95.2%) | Rate: 49.8 files/sec | Elapsed: 1143.7s | ETA: 57.7s
# Progress: 57024/59869 (95.2%) | Rate: 49.8 files/sec | Elapsed: 1144.5s | ETA: 57.1s
# Progress: 57056/59869 (95.3%) | Rate: 49.8 files/sec | Elapsed: 1145.1s | ETA: 56.5s
# Progress: 57088/59869 (95.4%) | Rate: 49.8 files/sec | Elapsed: 1145.7s | ETA: 55.8s
# Progress: 57120/59869 (95.4%) | Rate: 49.8 files/sec | Elapsed: 1146.4s | ETA: 55.2s
# Progress: 57152/59869 (95.5%) | Rate: 49.8 files/sec | Elapsed: 1147.1s | ETA: 54.5s
# Progress: 57184/59869 (95.5%) | Rate: 49.8 files/sec | Elapsed: 1147.9s | ETA: 53.9s
# Progress: 57216/59869 (95.6%) | Rate: 49.8 files/sec | Elapsed: 1148.6s | ETA: 53.3s
# Progress: 57248/59869 (95.6%) | Rate: 49.8 files/sec | Elapsed: 1149.2s | ETA: 52.6s
# Progress: 57280/59869 (95.7%) | Rate: 49.8 files/sec | Elapsed: 1149.7s | ETA: 52.0s
# Progress: 57312/59869 (95.7%) | Rate: 49.8 files/sec | Elapsed: 1150.4s | ETA: 51.3s
# Progress: 57344/59869 (95.8%) | Rate: 49.8 files/sec | Elapsed: 1151.3s | ETA: 50.7s
# Progress: 57376/59869 (95.8%) | Rate: 49.8 files/sec | Elapsed: 1151.9s | ETA: 50.0s
# Progress: 57408/59869 (95.9%) | Rate: 49.8 files/sec | Elapsed: 1152.4s | ETA: 49.4s
# Progress: 57440/59869 (95.9%) | Rate: 49.8 files/sec | Elapsed: 1153.1s | ETA: 48.8s
# Progress: 57472/59869 (96.0%) | Rate: 49.8 files/sec | Elapsed: 1153.8s | ETA: 48.1s
# Progress: 57504/59869 (96.0%) | Rate: 49.8 files/sec | Elapsed: 1154.6s | ETA: 47.5s
# Progress: 57536/59869 (96.1%) | Rate: 49.8 files/sec | Elapsed: 1155.2s | ETA: 46.8s
# Progress: 57568/59869 (96.2%) | Rate: 49.8 files/sec | Elapsed: 1155.8s | ETA: 46.2s
# Progress: 57600/59869 (96.2%) | Rate: 49.8 files/sec | Elapsed: 1156.4s | ETA: 45.6s
# Progress: 57632/59869 (96.3%) | Rate: 49.8 files/sec | Elapsed: 1157.1s | ETA: 44.9s
# Progress: 57664/59869 (96.3%) | Rate: 49.8 files/sec | Elapsed: 1158.0s | ETA: 44.3s
# Progress: 57696/59869 (96.4%) | Rate: 49.8 files/sec | Elapsed: 1158.6s | ETA: 43.6s
# Progress: 57728/59869 (96.4%) | Rate: 49.8 files/sec | Elapsed: 1159.3s | ETA: 43.0s
# Progress: 57760/59869 (96.5%) | Rate: 49.8 files/sec | Elapsed: 1159.9s | ETA: 42.4s
# Progress: 57792/59869 (96.5%) | Rate: 49.8 files/sec | Elapsed: 1160.5s | ETA: 41.7s
# Progress: 57824/59869 (96.6%) | Rate: 49.8 files/sec | Elapsed: 1161.3s | ETA: 41.1s
# Progress: 57856/59869 (96.6%) | Rate: 49.8 files/sec | Elapsed: 1162.0s | ETA: 40.4s
# Progress: 57888/59869 (96.7%) | Rate: 49.8 files/sec | Elapsed: 1162.7s | ETA: 39.8s
# Progress: 57920/59869 (96.7%) | Rate: 49.8 files/sec | Elapsed: 1163.4s | ETA: 39.1s
# Progress: 57952/59869 (96.8%) | Rate: 49.8 files/sec | Elapsed: 1164.0s | ETA: 38.5s
# Progress: 57984/59869 (96.9%) | Rate: 49.8 files/sec | Elapsed: 1164.7s | ETA: 37.9s
# Progress: 58016/59869 (96.9%) | Rate: 49.8 files/sec | Elapsed: 1165.3s | ETA: 37.2s
# Progress: 58048/59869 (97.0%) | Rate: 49.8 files/sec | Elapsed: 1166.0s | ETA: 36.6s
# Progress: 58080/59869 (97.0%) | Rate: 49.8 files/sec | Elapsed: 1166.6s | ETA: 35.9s
# Progress: 58112/59869 (97.1%) | Rate: 49.8 files/sec | Elapsed: 1167.3s | ETA: 35.3s
# Progress: 58144/59869 (97.1%) | Rate: 49.8 files/sec | Elapsed: 1168.0s | ETA: 34.7s
# Progress: 58176/59869 (97.2%) | Rate: 49.8 files/sec | Elapsed: 1168.7s | ETA: 34.0s
# Progress: 58208/59869 (97.2%) | Rate: 49.8 files/sec | Elapsed: 1169.3s | ETA: 33.4s
# Progress: 58240/59869 (97.3%) | Rate: 49.8 files/sec | Elapsed: 1170.0s | ETA: 32.7s
# Progress: 58272/59869 (97.3%) | Rate: 49.8 files/sec | Elapsed: 1170.7s | ETA: 32.1s
# Progress: 58304/59869 (97.4%) | Rate: 49.8 files/sec | Elapsed: 1171.5s | ETA: 31.4s
# Progress: 58336/59869 (97.4%) | Rate: 49.8 files/sec | Elapsed: 1172.1s | ETA: 30.8s
# Progress: 58368/59869 (97.5%) | Rate: 49.8 files/sec | Elapsed: 1172.9s | ETA: 30.2s
# Progress: 58400/59869 (97.5%) | Rate: 49.8 files/sec | Elapsed: 1173.4s | ETA: 29.5s
# Progress: 58432/59869 (97.6%) | Rate: 49.8 files/sec | Elapsed: 1174.0s | ETA: 28.9s
# Progress: 58464/59869 (97.7%) | Rate: 49.8 files/sec | Elapsed: 1174.8s | ETA: 28.2s
# Progress: 58496/59869 (97.7%) | Rate: 49.8 files/sec | Elapsed: 1175.5s | ETA: 27.6s
# Progress: 58528/59869 (97.8%) | Rate: 49.8 files/sec | Elapsed: 1176.0s | ETA: 26.9s
# Progress: 58560/59869 (97.8%) | Rate: 49.8 files/sec | Elapsed: 1176.7s | ETA: 26.3s
# Progress: 58592/59869 (97.9%) | Rate: 49.8 files/sec | Elapsed: 1177.4s | ETA: 25.7s
# Progress: 58624/59869 (97.9%) | Rate: 49.8 files/sec | Elapsed: 1178.3s | ETA: 25.0s
# Progress: 58656/59869 (98.0%) | Rate: 49.7 files/sec | Elapsed: 1179.0s | ETA: 24.4s
# Progress: 58688/59869 (98.0%) | Rate: 49.8 files/sec | Elapsed: 1179.6s | ETA: 23.7s
# Progress: 58720/59869 (98.1%) | Rate: 49.8 files/sec | Elapsed: 1180.3s | ETA: 23.1s
# Progress: 58752/59869 (98.1%) | Rate: 49.8 files/sec | Elapsed: 1180.9s | ETA: 22.5s
# Progress: 58784/59869 (98.2%) | Rate: 49.7 files/sec | Elapsed: 1181.7s | ETA: 21.8s
# Progress: 58816/59869 (98.2%) | Rate: 49.7 files/sec | Elapsed: 1182.4s | ETA: 21.2s
# Progress: 58848/59869 (98.3%) | Rate: 49.7 files/sec | Elapsed: 1183.0s | ETA: 20.5s
# Progress: 58880/59869 (98.3%) | Rate: 49.7 files/sec | Elapsed: 1183.9s | ETA: 19.9s
# Progress: 58912/59869 (98.4%) | Rate: 49.7 files/sec | Elapsed: 1184.6s | ETA: 19.2s
# Progress: 58944/59869 (98.5%) | Rate: 49.7 files/sec | Elapsed: 1185.4s | ETA: 18.6s
# Progress: 58976/59869 (98.5%) | Rate: 49.7 files/sec | Elapsed: 1186.1s | ETA: 18.0s
# Progress: 59008/59869 (98.6%) | Rate: 49.7 files/sec | Elapsed: 1186.7s | ETA: 17.3s
# Progress: 59040/59869 (98.6%) | Rate: 49.7 files/sec | Elapsed: 1187.3s | ETA: 16.7s
# Progress: 59072/59869 (98.7%) | Rate: 49.7 files/sec | Elapsed: 1187.9s | ETA: 16.0s
# Progress: 59104/59869 (98.7%) | Rate: 49.7 files/sec | Elapsed: 1188.8s | ETA: 15.4s
# Progress: 59136/59869 (98.8%) | Rate: 49.7 files/sec | Elapsed: 1189.3s | ETA: 14.7s
# Progress: 59168/59869 (98.8%) | Rate: 49.7 files/sec | Elapsed: 1189.9s | ETA: 14.1s
# Progress: 59200/59869 (98.9%) | Rate: 49.7 files/sec | Elapsed: 1190.5s | ETA: 13.5s
# Progress: 59232/59869 (98.9%) | Rate: 49.7 files/sec | Elapsed: 1191.1s | ETA: 12.8s
# Progress: 59264/59869 (99.0%) | Rate: 49.7 files/sec | Elapsed: 1191.9s | ETA: 12.2s
# Progress: 59296/59869 (99.0%) | Rate: 49.7 files/sec | Elapsed: 1192.5s | ETA: 11.5s
# Progress: 59328/59869 (99.1%) | Rate: 49.7 files/sec | Elapsed: 1193.1s | ETA: 10.9s
# Progress: 59360/59869 (99.1%) | Rate: 49.7 files/sec | Elapsed: 1193.7s | ETA: 10.2s
# Progress: 59392/59869 (99.2%) | Rate: 49.7 files/sec | Elapsed: 1194.4s | ETA: 9.6s
# Progress: 59424/59869 (99.3%) | Rate: 49.7 files/sec | Elapsed: 1195.2s | ETA: 9.0s
# Progress: 59456/59869 (99.3%) | Rate: 49.7 files/sec | Elapsed: 1195.9s | ETA: 8.3s
# Progress: 59488/59869 (99.4%) | Rate: 49.7 files/sec | Elapsed: 1196.6s | ETA: 7.7s
# Progress: 59520/59869 (99.4%) | Rate: 49.7 files/sec | Elapsed: 1197.2s | ETA: 7.0s
# Progress: 59552/59869 (99.5%) | Rate: 49.7 files/sec | Elapsed: 1197.8s | ETA: 6.4s
# Progress: 59584/59869 (99.5%) | Rate: 49.7 files/sec | Elapsed: 1198.4s | ETA: 5.7s
# Progress: 59616/59869 (99.6%) | Rate: 49.7 files/sec | Elapsed: 1199.2s | ETA: 5.1s
# Progress: 59648/59869 (99.6%) | Rate: 49.7 files/sec | Elapsed: 1199.8s | ETA: 4.4s
# Progress: 59680/59869 (99.7%) | Rate: 49.7 files/sec | Elapsed: 1200.4s | ETA: 3.8s
# Progress: 59712/59869 (99.7%) | Rate: 49.7 files/sec | Elapsed: 1201.0s | ETA: 3.2s
# Progress: 59744/59869 (99.8%) | Rate: 49.7 files/sec | Elapsed: 1201.8s | ETA: 2.5s
# Progress: 59776/59869 (99.8%) | Rate: 49.7 files/sec | Elapsed: 1202.4s | ETA: 1.9s
# Progress: 59808/59869 (99.9%) | Rate: 49.7 files/sec | Elapsed: 1203.0s | ETA: 1.2s
# Progress: 59840/59869 (100.0%) | Rate: 49.7 files/sec | Elapsed: 1203.6s | ETA: 0.6s
# Progress: 59869/59869 (100.0%) | Rate: 49.7 files/sec | Elapsed: 1204.2s | ETA: 0.0s
#
# ✓ Feature extraction complete!
# Total time: 1204.34 seconds (20.07 minutes)
# Average: 0.020 seconds per file
# Processing rate: 49.71 files/second
#
# Successful: 59869/59869
# Failed: 0/59869

# %% [markdown]
# ## 7. Organize Features into Arrays

# %%
print('\nOrganizing features into arrays...')

# Filter only successful results
successful_indices = [i for i, r in enumerate(results) if r['success']]
successful_results = [results[i] for i in successful_indices]
successful_labels = labels[successful_indices]

# Extract feature arrays
mfcc_features = np.array([r['mfcc'] for r in successful_results])
gfcc_features = np.array([r['gfcc'] for r in successful_results])
combined_features = np.array([r['combined'] for r in successful_results])

print(f'MFCC features shape: {mfcc_features.shape}')
print(f'GFCC features shape: {gfcc_features.shape}')
print(f'Combined features shape: {combined_features.shape}')
print(f'Labels shape: {successful_labels.shape}')

# Log feature dimensions
mlflow.log_param('mfcc_feature_dim', mfcc_features.shape[1])
mlflow.log_param('gfcc_feature_dim', gfcc_features.shape[1])
mlflow.log_param('combined_feature_dim', combined_features.shape[1])

# Verify no NaN or Inf values
for name, feats in [('MFCC', mfcc_features), ('GFCC', gfcc_features), ('Combined', combined_features)]:
    n_nan = np.isnan(feats).sum()
    n_inf = np.isinf(feats).sum()
    print(f'{name}: NaN={n_nan}, Inf={n_inf}')
    
    if n_nan > 0 or n_inf > 0:
        print(f'  WARNING: {name} contains invalid values!')
        # Replace NaN with 0 and Inf with large values
        feats[np.isnan(feats)] = 0
        feats[np.isinf(feats)] = np.sign(feats[np.isinf(feats)]) * 1e10

print('\n✓ Features organized and validated')
# Out:
# Organizing features into arrays...
# MFCC features shape: (59869, 52)
# GFCC features shape: (59869, 52)
# Combined features shape: (59869, 248)
# Labels shape: (59869,)
# MFCC: NaN=0, Inf=0
# GFCC: NaN=0, Inf=0
# Combined: NaN=192, Inf=0
#   WARNING: Combined contains invalid values!
#
# ✓ Features organized and validated

# %% [markdown]
# ## 8. Save Features

# %%
# Save feature arrays
mfcc_path = FEATURES_DIR / 'mfcc_unbalanced_features_44khz.npy'
gfcc_path = FEATURES_DIR / 'gfcc_unbalanced_features_44khz.npy'
combined_path = FEATURES_DIR / 'combined_unbalanced_features_44khz.npy'
labels_path = FEATURES_DIR / 'labels_44khz.npy'

np.save(mfcc_path, mfcc_features)
np.save(gfcc_path, gfcc_features)
np.save(combined_path, combined_features)
np.save(labels_path, successful_labels)

print('Features saved:')
print(f'  MFCC: {mfcc_path}')
print(f'  GFCC: {gfcc_path}')
print(f'  Combined: {combined_path}')
print(f'  Labels: {labels_path}')

# Log artifacts to MLflow
mlflow.log_artifact(str(mfcc_path))
mlflow.log_artifact(str(gfcc_path))
mlflow.log_artifact(str(combined_path))
mlflow.log_artifact(str(labels_path))

# Create metadata
metadata = {
    'timestamp': datetime.now().isoformat(),
    'sample_rate': SAMPLE_RATE,
    'n_fft': N_FFT,
    'hop_length': HOP_LENGTH,
    'n_mfcc': N_MFCC,
    'n_gfcc': N_GFCC,
    'total_samples': len(successful_labels),
    'mfcc_dim': mfcc_features.shape[1],
    'gfcc_dim': gfcc_features.shape[1],
    'combined_dim': combined_features.shape[1],
    'extraction_time_seconds': extraction_time,
    'gpu_enabled': USE_GPU,
    'device': str(device),
    'n_workers': N_WORKERS,
    'class_distribution': df['class'].value_counts().to_dict()
}

metadata_path = FEATURES_DIR / 'metadata_44khz.json'
with open(metadata_path, 'w') as f:
    json.dump(metadata, f, indent=2)

print(f'\nMetadata saved: {metadata_path}')
mlflow.log_artifact(str(metadata_path))

print('\n✓ All features and metadata saved successfully!')
# Out:
# Features saved:
#   MFCC: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/features/classical/mfcc_unbalanced_features_44khz.npy
#   GFCC: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/features/classical/gfcc_unbalanced_features_44khz.npy
#   Combined: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/features/classical/combined_unbalanced_features_44khz.npy
#   Labels: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/features/classical/labels_44khz.npy
#
# Metadata saved: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/features/classical/metadata_44khz.json
#
# ✓ All features and metadata saved successfully!

# %% [markdown]
# ## 9. Feature Statistics and Summary

# %%
print('\n' + '=' * 80)
print('FEATURE EXTRACTION SUMMARY (44.1kHz)')
print('=' * 80)

print(f'Sample Rate: {SAMPLE_RATE} Hz')
print(f'FFT Size: {N_FFT}')
print(f'Hop Length: {HOP_LENGTH}')
print(f'\nTotal Samples Processed: {len(successful_labels)}')
print(f'Success Rate: {len(successful_labels)/len(audio_files)*100:.2f}%')

print(f'\nFeature Dimensions:')
print(f'  MFCC-only: {mfcc_features.shape[1]} features')
print(f'  GFCC-only: {gfcc_features.shape[1]} features')
print(f'  Combined: {combined_features.shape[1]} features')

print(f'\nPerformance:')
print(f'  Total Time: {extraction_time/60:.2f} minutes')
print(f'  Avg Time/File: {extraction_time/len(audio_files):.3f} seconds')
print(f'  Processing Rate: {len(audio_files)/extraction_time:.2f} files/sec')
print(f'  GPU Enabled: {USE_GPU}')
print(f'  Workers: {N_WORKERS}')

print(f'\nClass Distribution:')
for class_name, count in sorted(df['class'].value_counts().items()):
    print(f'  {class_name}: {count}')

print('\nFeature Range Statistics (Combined):')
print(f'  Min: {combined_features.min():.4f}')
print(f'  Max: {combined_features.max():.4f}')
print(f'  Mean: {combined_features.mean():.4f}')
print(f'  Std: {combined_features.std():.4f}')

print('=' * 80)

# Create summary dict
summary = {
    'sample_rate_hz': SAMPLE_RATE,
    'n_fft': N_FFT,
    'hop_length': HOP_LENGTH,
    'total_samples': len(successful_labels),
    'success_rate': len(successful_labels)/len(audio_files),
    'mfcc_dim': int(mfcc_features.shape[1]),
    'gfcc_dim': int(gfcc_features.shape[1]),
    'combined_dim': int(combined_features.shape[1]),
    'extraction_time_minutes': extraction_time/60,
    'avg_time_per_file_seconds': extraction_time/len(audio_files),
    'processing_rate_files_per_sec': len(audio_files)/extraction_time,
    'gpu_enabled': USE_GPU,
    'device': str(device),
    'n_workers': N_WORKERS
}

summary_path = FEATURES_DIR / 'extraction_summary_44khz.json'
with open(summary_path, 'w') as f:
    json.dump(summary, f, indent=2)

mlflow.log_artifact(str(summary_path))

print(f'Summary saved: {summary_path}')
# Out:
# ================================================================================
# FEATURE EXTRACTION SUMMARY (44.1kHz)
# ================================================================================
# Sample Rate: 44100 Hz
# FFT Size: 2048
# Hop Length: 441
#
# Total Samples Processed: 59869
# Success Rate: 100.00%
#
# Feature Dimensions:
#   MFCC-only: 52 features
#   GFCC-only: 52 features
#   Combined: 248 features
#
# Performance:
#   Total Time: 20.07 minutes
#   Avg Time/File: 0.020 seconds
#   Processing Rate: 49.71 files/sec
#   GPU Enabled: True
#   Workers: 8
#
# Class Distribution:
#   background: 8069
#   grinder: 32792
#   tools: 19008
#
# Feature Range Statistics (Combined):
#   Min: -632.4561
#   Max: 7295.4919
#   Mean: 48.1426
#   Std: 434.0542
# ================================================================================
# Summary saved: /Users/harryirving/Development/projects/ai-ml/BikeAIv5/data/features/classical/extraction_summary_44khz.json

# %% [markdown]
# ## 10. Performance Comparison Note

# %% [markdown]
# ### Expected Performance Improvements
#
# This optimized notebook should provide significant speedup compared to the standard 16kHz version:
#
# **Optimizations Applied:**
# 1. **GPU Acceleration (torchaudio)**: 5-10x speedup for MFCC extraction on M4 Mac
# 2. **Parallel Processing**: 2-4x speedup using ThreadPool with multiple cores
# 3. **Batch Processing**: Efficient memory management and progress tracking
# 4. **Memory Management**: Garbage collection prevents kernel crashes
#
# **Expected Results:**
# - Original 16kHz (librosa only): ~20-30 minutes
# - Original 44.1kHz (librosa only): ~40+ minutes (crashed)
# - **Optimized 44.1kHz (this notebook): ~5-10 minutes**
#
# **Note:** Even with optimizations, you'll need to evaluate whether the additional high-frequency information (8-22 kHz) provides meaningful classification improvements. Consider:
# - Training models on both 16kHz and 44.1kHz features
# - Comparing accuracy, F1-score, and inference time
# - Remember: YAMNet requires 16kHz anyway, so this primarily benefits classical ML models
#
# **Next Steps:**
# 1. Run this notebook and measure actual extraction time
# 2. Train models using `05_classical_training_and_tuning.ipynb` with these 44kHz features
# 3. Compare performance metrics with 16kHz baseline
# 4. Make an informed decision based on the accuracy vs. computational cost trade-off

# %% [markdown]
# ## Notebook Complete
#
# Features extracted and saved. Check the summary above for performance metrics.
